# %% [markdown]
# # Setup

# %% [markdown]
# ## Instructions
# 1. Download this notebook, and open in it in Jupyer, JupyerLab, VSCode, etc.

# %% [markdown]
# Set the following environment variable before loading any packages. This will make sure Octofitter can take advantage of all available threads on your computer.

# %%
# %env JULIA_NUM_THREADS=auto
# %env OCTOFITTERPY_AUTOLOAD_EXTENSIONS='yes'
# Out:
# env: JULIA_NUM_THREADS=auto
# env: OCTOFITTERPY_AUTOLOAD_EXTENSIONS='yes'

# %% [markdown]
# The first time you import octofitterpy, we will automatically install Julia (via JuliaUp) and compile Octofitter.jl in a self-contained environment. Subsequent imports will be faster.

# %%
import octofitterpy as octo
# Out:
# [juliapkg] Found dependencies: c:\users\macke\anaconda3\envs\octo\lib\site-packages\juliapkg\juliapkg.json
# [juliapkg] Found dependencies: c:\users\macke\anaconda3\envs\octo\lib\site-packages\octofitterpy\juliapkg.json
# [juliapkg] Found dependencies: c:\users\macke\anaconda3\envs\octo\lib\site-packages\juliacall\juliapkg.json
# [juliapkg] Locating Julia =1.10.6
# [juliapkg] WARNING: You have Julia 1.11.5 installed but =1.10.6 is required.
# [juliapkg]   It is recommended that you upgrade Julia or install JuliaUp.
# [juliapkg] Querying Julia versions from https://julialang-s3.julialang.org/bin/versions.json
# [juliapkg] WARNING: About to install Julia 1.10.6 to C:\Users\macke\anaconda3\envs\octo\julia_env\pyjuliapkg\install.
# [juliapkg]   If you use juliapkg in more than one environment, you are likely to
# [juliapkg]   have Julia installed in multiple locations. It is recommended to
# [juliapkg]   install JuliaUp (https://github.com/JuliaLang/juliaup) or Julia
# [juliapkg]   (https://julialang.org/downloads) yourself.
# [juliapkg] Downloading Julia from https://julialang-s3.julialang.org/bin/winnt/x64/1.10/julia-1.10.6-win64.zip
#              downloaded 23.9 MB of 170.7 MB
#              downloaded 64.6 MB of 170.7 MB
#              downloaded 106.4 MB of 170.7 MB
#              downloaded 148.4 MB of 170.7 MB
#              download complete
# [juliapkg] Verifying download
# [juliapkg] Installing Julia 1.10.6 to C:\Users\macke\anaconda3\envs\octo\julia_env\pyjuliapkg\install
# [juliapkg] Using Julia 1.10.6 at C:\Users\macke\anaconda3\envs\octo\julia_env\pyjuliapkg\install\bin\julia.exe
# [juliapkg] Using Julia project at C:\Users\macke\anaconda3\envs\octo\julia_env
# [juliapkg] Writing Project.toml:
#              [deps]
#              Octofitter = "daf3887e-d01a-44a1-9d7e-98f15c5d69c9"
#              OctofitterRadialVelocity = "c6a353d9-c9c1-48aa-9c23-64f4679bd07d"
#              Distributions = "31c24e10-a181-5473-b8eb-7969acd0382f"
#              CairoMakie = "13f3f980-e62b-5c42-98c6-ff1f3baf88f0"
#              PairPlots = "43a3c2be-4208-490b-832a-a21dcd55d7da"
#              Pigeons = "0eb8d820-af6a-4919-95ae-11206f830c31"
#              PythonCall = "6099a3de-0909-46bc-b1f4-468b9a2dfc0d"
#              [compat]
#              Octofitter = "=5.2.1"
#              OctofitterRadialVelocity = "=5.1.0"
#              Distributions = "^0.25.112"
#              CairoMakie = "^0.12.15"
#              PairPlots = "^2.9.3"
#              Pigeons = "^0.4.7"
#              PythonCall = "=0.9.23"
# [juliapkg] Installing packages:
#              import Pkg
#              Pkg.Registry.update()
#              Pkg.add([
#                Pkg.PackageSpec(name="Octofitter", uuid="daf3887e-d01a-44a1-9d7e-98f15c5d69c9"),
#                Pkg.PackageSpec(name="OctofitterRadialVelocity", uuid="c6a353d9-c9c1-48aa-9c23-64f4679bd07d"),
#                Pkg.PackageSpec(name="Distributions", uuid="31c24e10-a181-5473-b8eb-7969acd0382f"),
#                Pkg.PackageSpec(name="CairoMakie", uuid="13f3f980-e62b-5c42-98c6-ff1f3baf88f0"),
#                Pkg.PackageSpec(name="PairPlots", uuid="43a3c2be-4208-490b-832a-a21dcd55d7da"),
#                Pkg.PackageSpec(name="Pigeons", uuid="0eb8d820-af6a-4919-95ae-11206f830c31"),
#                Pkg.PackageSpec(name="PythonCall", uuid="6099a3de-0909-46bc-b1f4-468b9a2dfc0d"),
#              ])
#              Pkg.resolve()
#              Pkg.precompile()
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython
# C:\Users\macke\anaconda3\envs\octo\Lib\site-packages\octofitterpy\julia_import.py:60: UserWarning: OCTOFITTERPY_AUTOLOAD_EXTENSIONS environment variable is set to something other than 'yes' or 'no' or ''.
#   warnings.warn(

# %% [markdown]
# # Fit Relative Astrometry

# %% [markdown]
# We start by defining a likelihood object for our data, in this case relative astrometry of the planet.

# %%
astrom_like = octo.PlanetRelAstromLikelihood(
    # MJD
    epoch = [50000,50120,50240,50360,50480,50600,50720,50840],
    # delta RA, milliarcseconds (East is positive)
    ra = [-505.7,-502.5,-498.2,-492.6,-485.9,-478.1,-469.0,-458.8],
    # delta DEC, milliarcseconds (North is positive)
    dec = [-66.9,-37.4,-7.9,21.6,51.1,80.5,109.7,138.6],
    # Uncertainty on RA, milliarcseconds
    σ_ra = [10,10,10,10,10,10,10,10.0],
    # Uncertainty on DEC, milliarcseconds
	σ_dec = [10,10,10,10,10,10,10,10],
    # Corelation between RA and DEC uncertainties
	cor= [0,0,0,0,0,0,0,0.0]
)
astrom_like
# Out:
# PlanetRelAstromLikelihood Table with 6 columns and 8 rows:
#      cor  σ_ra  σ_dec  ra      dec    epoch
#    ┌───────────────────────────────────────
#  1 │ 0.0  10.0  10     -505.7  -66.9  50000
#  2 │ 0.0  10.0  10     -502.5  -37.4  50120
#  3 │ 0.0  10.0  10     -498.2  -7.9   50240
#  4 │ 0.0  10.0  10     -492.6  21.6   50360
#  5 │ 0.0  10.0  10     -485.9  51.1   50480
#  6 │ 0.0  10.0  10     -478.1  80.5   50600
#  7 │ 0.0  10.0  10     -469.0  109.7  50720
#  8 │ 0.0  10.0  10     -458.8  138.6  50840

# %% [markdown]
# If your dates aren't in MJD format, you might use one of these functions to convert:
#
# **To convert dates:**
# *  `octo.mjd("2020-01-01")` -> to MJD
# *  `octo.years2mjd("2020.0")` -> to MJD
# *  convert back: `octo.mjd2date(50000)` -> `datetime.date(1995, 10, 10)`

# %% [markdown]
# You could also define the astrometry using a separation & position angle format:
# ```python
# # You can also use separation (milliarcseconds) and position angle (RADIANS):
# astrom_like = octo.PlanetRelAstromLikelihood(
#     # MJD
#     epoch = [50000,50120],
#     # separation from star, milliarcseconds (East is positive)
#     sep = [505.7,600.1],
#     # position angle, RADIANS (!!) (NOT DEGREES)
#     pa = [0.0,0.4,],
#     # Uncertainty on sep, milliarcseconds
#     σ_sep = [10,10],
#     # Uncertainty on pa, RADIANS
# 	σ_pa = [0.01,0.01],
#     # Corelation between PA and SEP uncertainties
#     cor= [0,0.2]
# )
# ```

# %% [markdown]
# We now define the planet component of our model. We specify a name, an orbital basis, our priors, and list any likelihood objects.
#
# Note! Change the reference epoch provided to `θ_at_epoch_to_tperi` from 50000 to one where your astrometry is defined. This is critical for good performance.

# %%
planet_b = octo.Planet(
    name="b",
    basis="Visual{KepOrbit}",
    priors=
    """            
        a ~ LogUniform(0.1, 500)
        e ~ Uniform(0.0, 0.99)
        i ~ Sine()
        ω ~ UniformCircular()
        Ω ~ UniformCircular()
        θ ~ UniformCircular()
        tp = θ_at_epoch_to_tperi(system,b,50000) # use MJD epoch of your data here!!
    """,
    likelihoods=[astrom_like]
)

# %% [markdown]
# Now we define our system, containing our planet. We provide it with a name (used to specofy the output file names and plot legends), our priors, a list of lieklihood objects for the system as a whole (eg proper motion anomaly, radial velocity), and a list of companion models.

# %%
# The name of your system determines the output file names
sys = octo.System(
    name="HIP100123",
    priors = 
    """
        M ~ truncated(Normal(1.2, 0.1), lower=0)
        plx ~ truncated(Normal(50.0, 0.02), lower=0)
    """,
    likelihoods=[],
    companions=[planet_b]
)

# %% [markdown]
# We then compile our model. There are a few options for this function (for example, you can select the autodiff backend), but the defaults are reasonable.

# %%
model = octo.LogDensityModel(sys)

# %% [markdown]
# We now fit the model. By default this uses a Hamiltonian Monte Carlo sampler with 1000 steps of adaptation (discarded) and 1000 iterations. You can pass eg. `adaptation=5000, iterations=25000` if you would like more points for your plots.

# %%
chain = octo.octofit(model)
# Out:
# [ Info: Determining initial positions and metric using pathfinder
# ┌ Info: Found a sample of initial positions
# └   initial_logpost_range = (-65.35084696677158, -51.87124920864591)
# [ Info: Sampling, beginning with adaptation phase...
# Sampling   0%|█                              |  ETA: 0:38:49
#                                     iterations: 2
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.5
#                                        n_steps: 2
#                                      is_accept: true
#                                acceptance_rate: 2.185083189879603e-131
#                                    log_density: -55.744143993433354
#                             hamiltonian_energy: 57.93033244472819
#                       hamiltonian_energy_error: 0.0
#                   max_hamiltonian_energy_error: 1633.6542004788146
#                                     tree_depth: 1
#                                numerical_error: true
#                                      step_size: 0.21832258351082898
#                                  nom_step_size: 0.21832258351082898
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.003017770291167465, 1.31 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   4%|██                             |  ETA: 0:01:50
#                                     iterations: 73
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.05
#                                        n_steps: 255
#                                      is_accept: true
#                                acceptance_rate: 0.9779033803864061
#                                    log_density: -54.80250961462227
#                             hamiltonian_energy: 60.42542775639934
#                       hamiltonian_energy_error: -0.07012600084390641
#                   max_hamiltonian_energy_error: 0.08184872160274637
#                                     tree_depth: 7
#                                numerical_error: false
#                                      step_size: 0.029489146993894103
#                                  nom_step_size: 0.029489146993894103
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.003017770291167465, 1.31 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   6%|██                             |  ETA: 0:01:15
#                                     iterations: 123
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.1
#                                        n_steps: 127
#                                      is_accept: true
#                                acceptance_rate: 0.9897470442006691
#                                    log_density: -59.703587085806745
#                             hamiltonian_energy: 65.48962910374988
#                       hamiltonian_energy_error: 0.01888964839102414
#                   max_hamiltonian_energy_error: -0.04633077436429289
#                                     tree_depth: 7
#                                numerical_error: false
#                                      step_size: 0.008377705072248009
#                                  nom_step_size: 0.008377705072248009
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.005558226470479768, 0.00 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   6%|██                             |  ETA: 0:01:15
#                                     iterations: 129
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.1
#                                        n_steps: 511
#                                      is_accept: true
#                                acceptance_rate: 0.9876764425431073
#                                    log_density: -54.62222680424525
#                             hamiltonian_energy: 64.81974341375069
#                       hamiltonian_energy_error: -0.20288145507538502
#                   max_hamiltonian_energy_error: -0.8940276486833341
#                                     tree_depth: 8
#                                numerical_error: false
#                                      step_size: 0.020867385005697084
#                                  nom_step_size: 0.020867385005697084
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.005558226470479768, 0.00 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   7%|███                            |  ETA: 0:01:09
#                                     iterations: 149
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.09
#                                        n_steps: 62
#                                      is_accept: true
#                                acceptance_rate: 0.33462185287569746
#                                    log_density: -54.081969951577456
#                             hamiltonian_energy: 59.400402659097566
#                       hamiltonian_energy_error: 0.37419047001495187
#                   max_hamiltonian_energy_error: 1680.3417315846714
#                                     tree_depth: 5
#                                numerical_error: true
#                                      step_size: 0.0496503659995261
#                                  nom_step_size: 0.0496503659995261
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.005558226470479768, 0.00 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   8%|███                            |  ETA: 0:01:07
#                                     iterations: 157
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.1
#                                        n_steps: 383
#                                      is_accept: true
#                                acceptance_rate: 0.8568555840786471
#                                    log_density: -57.84042333801578
#                             hamiltonian_energy: 61.83763005923465
#                       hamiltonian_energy_error: 0.19960925166167698
#                   max_hamiltonian_energy_error: 0.3216297685086502
#                                     tree_depth: 8
#                                numerical_error: false
#                                      step_size: 0.01726016262952141
#                                  nom_step_size: 0.01726016262952141
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.00515924056773485, 9.105 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   9%|███                            |  ETA: 0:01:02
#                                     iterations: 171
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.11
#                                        n_steps: 1023
#                                      is_accept: true
#                                acceptance_rate: 0.998555390060551
#                                    log_density: -58.01969779106277
#                             hamiltonian_energy: 60.2873804322278
#                       hamiltonian_energy_error: -0.048798238425206364
#                   max_hamiltonian_energy_error: -0.4872815626605487
#                                     tree_depth: 9
#                                numerical_error: false
#                                      step_size: 0.009966333374003874
#                                  nom_step_size: 0.009966333374003874
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.00515924056773485, 9.105 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   9%|███                            |  ETA: 0:01:00
#                                     iterations: 182
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.1
#                                        n_steps: 511
#                                      is_accept: true
#                                acceptance_rate: 0.9938985673045463
#                                    log_density: -56.2853911297725
#                             hamiltonian_energy: 58.624151995845736
#                       hamiltonian_energy_error: -0.10507325202982543
#                   max_hamiltonian_energy_error: -0.11080244076803325
#                                     tree_depth: 9
#                                numerical_error: false
#                                      step_size: 0.010052255654122967
#                                  nom_step_size: 0.010052255654122967
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.00515924056773485, 9.105 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  10%|███                            |  ETA: 0:00:58
#                                     iterations: 190
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.1
#                                        n_steps: 2063
#                                      is_accept: true
#                                acceptance_rate: 0.9543186579352231
#                                    log_density: -55.32727920890173
#                             hamiltonian_energy: 60.709293768722674
#                       hamiltonian_energy_error: 0.12874915024392664
#                   max_hamiltonian_energy_error: 0.18835518017110786
#                                     tree_depth: 11
#                                numerical_error: false
#                                      step_size: 0.011179558813643445
#                                  nom_step_size: 0.011179558813643445
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.00515924056773485, 9.105 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  10%|████                           |  ETA: 0:00:58
#                                     iterations: 196
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.1
#                                        n_steps: 255
#                                      is_accept: true
#                                acceptance_rate: 0.23346155896297352
#                                    log_density: -55.683099437559406
#                             hamiltonian_energy: 59.83197642382701
#                       hamiltonian_energy_error: -0.6828335423144551
#                   max_hamiltonian_energy_error: 137.25378948732273
#                                     tree_depth: 8
#                                numerical_error: false
#                                      step_size: 0.026089964863145045
#                                  nom_step_size: 0.026089964863145045
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.00515924056773485, 9.105 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  10%|████                           |  ETA: 0:00:57
#                                     iterations: 204
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.1
#                                        n_steps: 1023
#                                      is_accept: true
#                                acceptance_rate: 0.9929527149589635
#                                    log_density: -56.787645370099256
#                             hamiltonian_energy: 67.32817889157604
#                       hamiltonian_energy_error: -0.04397996084195199
#                   max_hamiltonian_energy_error: -0.04900847366788241
#                                     tree_depth: 9
#                                numerical_error: false
#                                      step_size: 0.0044681494774718635
#                                  nom_step_size: 0.0044681494774718635
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.00515924056773485, 9.105 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  10%|████                           |  ETA: 0:00:56
#                                     iterations: 209
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.1
#                                        n_steps: 511
#                                      is_accept: true
#                                acceptance_rate: 0.9865283723366148
#                                    log_density: -53.79301134944938
#                             hamiltonian_energy: 55.54988994324963
#                       hamiltonian_energy_error: -0.015076518354547375
#                   max_hamiltonian_energy_error: 0.03616483042959828
#                                     tree_depth: 8
#                                numerical_error: false
#                                      step_size: 0.006872460048613613
#                                  nom_step_size: 0.006872460048613613
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.00515924056773485, 9.105 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  11%|████                           |  ETA: 0:00:55
#                                     iterations: 216
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.1
#                                        n_steps: 959
#                                      is_accept: true
#                                acceptance_rate: 0.9999956261185085
#                                    log_density: -56.93165144375415
#                             hamiltonian_energy: 62.69212348892429
#                       hamiltonian_energy_error: -0.08802467572682815
#                   max_hamiltonian_energy_error: -0.23119636853581937
#                                     tree_depth: 9
#                                numerical_error: false
#                                      step_size: 0.011877139179232473
#                                  nom_step_size: 0.011877139179232473
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.00515924056773485, 9.105 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  12%|████                           |  ETA: 0:00:52
#                                     iterations: 232
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.09
#                                        n_steps: 511
#                                      is_accept: true
#                                acceptance_rate: 0.9946344997094566
#                                    log_density: -56.03199488985367
#                             hamiltonian_energy: 59.23210497399944
#                       hamiltonian_energy_error: -0.047847074193100525
#                   max_hamiltonian_energy_error: -0.16476657651337234
#                                     tree_depth: 8
#                                numerical_error: false
#                                      step_size: 0.01758770527940068
#                                  nom_step_size: 0.01758770527940068
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.00515924056773485, 9.105 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  12%|████                           |  ETA: 0:00:51
#                                     iterations: 243
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.1
#                                        n_steps: 127
#                                      is_accept: true
#                                acceptance_rate: 0.6166786033425778
#                                    log_density: -53.52450898699101
#                             hamiltonian_energy: 59.115306004793375
#                       hamiltonian_energy_error: -0.04599385543694723
#                   max_hamiltonian_energy_error: 1.4913313147436966
#                                     tree_depth: 7
#                                numerical_error: false
#                                      step_size: 0.01687842406637993
#                                  nom_step_size: 0.01687842406637993
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.00515924056773485, 9.105 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  12%|████                           |  ETA: 0:00:50
#                                     iterations: 250
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.1
#                                        n_steps: 127
#                                      is_accept: true
#                                acceptance_rate: 0.9987359822379928
#                                    log_density: -56.82962901816511
#                             hamiltonian_energy: 65.15249366159588
#                       hamiltonian_energy_error: 0.0011247105771730048
#                   max_hamiltonian_energy_error: -0.18272639025846615
#                                     tree_depth: 7
#                                numerical_error: false
#                                      step_size: 0.011624184020987473
#                                  nom_step_size: 0.011624184020987473
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.007024487633385507, 4.77 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  14%|█████                          |  ETA: 0:00:45
#                                     iterations: 290
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.1
#                                        n_steps: 127
#                                      is_accept: true
#                                acceptance_rate: 0.9892428868037086
#                                    log_density: -58.716203189156204
#                             hamiltonian_energy: 62.745271061656275
#                       hamiltonian_energy_error: 0.03614545799921842
#                   max_hamiltonian_energy_error: 1.046019801330722
#                                     tree_depth: 6
#                                numerical_error: false
#                                      step_size: 0.037487837786974836
#                                  nom_step_size: 0.037487837786974836
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.007024487633385507, 4.77 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  16%|█████                          |  ETA: 0:00:43
#                                     iterations: 311
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.1
#                                        n_steps: 127
#                                      is_accept: true
#                                acceptance_rate: 0.9650908352056792
#                                    log_density: -57.0045339942765
#                             hamiltonian_energy: 64.54567925214384
#                       hamiltonian_energy_error: -0.02944168380294343
#                   max_hamiltonian_energy_error: -0.26919353181780536
#                                     tree_depth: 7
#                                numerical_error: false
#                                      step_size: 0.024948780901797776
#                                  nom_step_size: 0.024948780901797776
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.007024487633385507, 4.77 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  16%|██████                         |  ETA: 0:00:41
#                                     iterations: 328
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.09
#                                        n_steps: 191
#                                      is_accept: true
#                                acceptance_rate: 0.8113411465999285
#                                    log_density: -56.14512741238731
#                             hamiltonian_energy: 62.14992824809593
#                       hamiltonian_energy_error: 0.19618201218693088
#                   max_hamiltonian_energy_error: 0.4396466323186772
#                                     tree_depth: 7
#                                numerical_error: false
#                                      step_size: 0.02027845283315132
#                                  nom_step_size: 0.02027845283315132
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.007024487633385507, 4.77 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  17%|██████                         |  ETA: 0:00:39
#                                     iterations: 345
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.09
#                                        n_steps: 127
#                                      is_accept: true
#                                acceptance_rate: 0.9968866232844704
#                                    log_density: -57.08537519841
#                             hamiltonian_energy: 63.19629650439139
#                       hamiltonian_energy_error: -0.004893282317063097
#                   max_hamiltonian_energy_error: -0.14345857008087393
#                                     tree_depth: 6
#                                numerical_error: false
#                                      step_size: 0.023385352886313545
#                                  nom_step_size: 0.023385352886313545
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.007024487633385507, 4.77 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  18%|██████                         |  ETA: 0:00:36
#                                     iterations: 369
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.09
#                                        n_steps: 767
#                                      is_accept: true
#                                acceptance_rate: 0.995467140762441
#                                    log_density: -53.717398062448424
#                             hamiltonian_energy: 58.382664621752554
#                       hamiltonian_energy_error: 0.007940550649934153
#                   max_hamiltonian_energy_error: -0.0710162336316742
#                                     tree_depth: 9
#                                numerical_error: false
#                                      step_size: 0.007297885429194887
#                                  nom_step_size: 0.007297885429194887
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.007024487633385507, 4.77 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  20%|███████                        |  ETA: 0:00:35
#                                     iterations: 391
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.09
#                                        n_steps: 255
#                                      is_accept: true
#                                acceptance_rate: 0.9340838781154658
#                                    log_density: -53.70270927785145
#                             hamiltonian_energy: 58.306844276651624
#                       hamiltonian_energy_error: -0.028935452583574772
#                   max_hamiltonian_energy_error: 0.18508669174582337
#                                     tree_depth: 8
#                                numerical_error: false
#                                      step_size: 0.015032630758395456
#                                  nom_step_size: 0.015032630758395456
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.007024487633385507, 4.77 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  21%|███████                        |  ETA: 0:00:33
#                                     iterations: 415
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.09
#                                        n_steps: 48
#                                      is_accept: true
#                                acceptance_rate: 0.11202930561869819
#                                    log_density: -59.29867871786393
#                             hamiltonian_energy: 62.57722191390644
#                       hamiltonian_energy_error: 0.031078227264522695
#                   max_hamiltonian_energy_error: 1335.6224788136842
#                                     tree_depth: 5
#                                numerical_error: true
#                                      step_size: 0.03511941528892641
#                                  nom_step_size: 0.03511941528892641
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.007024487633385507, 4.77 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  22%|███████                        |  ETA: 0:00:31
#                                     iterations: 438
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.09
#                                        n_steps: 63
#                                      is_accept: true
#                                acceptance_rate: 0.9548547739779445
#                                    log_density: -53.64553901694407
#                             hamiltonian_energy: 58.46315441428689
#                       hamiltonian_energy_error: 0.07353295426840845
#                   max_hamiltonian_energy_error: 0.256669444536648
#                                     tree_depth: 5
#                                numerical_error: false
#                                      step_size: 0.0397898187046237
#                                  nom_step_size: 0.0397898187046237
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.007024487633385507, 4.77 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  23%|████████                       |  ETA: 0:00:29
#                                     iterations: 465
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.09
#                                        n_steps: 63
#                                      is_accept: true
#                                acceptance_rate: 0.7157699957547231
#                                    log_density: -54.73199268613833
#                             hamiltonian_energy: 56.67552542523583
#                       hamiltonian_energy_error: 0.08237964045667923
#                   max_hamiltonian_energy_error: 1.5085582376240794
#                                     tree_depth: 6
#                                numerical_error: false
#                                      step_size: 0.036619385157203026
#                                  nom_step_size: 0.036619385157203026
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.006691981555683051, 2.46 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  24%|████████                       |  ETA: 0:00:28
#                                     iterations: 488
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.09
#                                        n_steps: 15
#                                      is_accept: true
#                                acceptance_rate: 0.1766686276483653
#                                    log_density: -55.2386096278568
#                             hamiltonian_energy: 58.70829564290422
#                       hamiltonian_energy_error: -1.2910597605980456
#                   max_hamiltonian_energy_error: 1706.6846688133326
#                                     tree_depth: 3
#                                numerical_error: true
#                                      step_size: 0.04096844836848812
#                                  nom_step_size: 0.04096844836848812
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.006691981555683051, 2.46 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  25%|████████                       |  ETA: 0:00:27
#                                     iterations: 504
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.1
#                                        n_steps: 255
#                                      is_accept: true
#                                acceptance_rate: 0.9760144348800815
#                                    log_density: -56.404472319160504
#                             hamiltonian_energy: 58.817062002671484
#                       hamiltonian_energy_error: 0.016105064132979408
#                   max_hamiltonian_energy_error: 0.053829312476885605
#                                     tree_depth: 8
#                                numerical_error: false
#                                      step_size: 0.010692381766755512
#                                  nom_step_size: 0.010692381766755512
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.006691981555683051, 2.46 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  27%|█████████                      |  ETA: 0:00:25
#                                     iterations: 538
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.1
#                                        n_steps: 63
#                                      is_accept: true
#                                acceptance_rate: 0.996344911335995
#                                    log_density: -57.30141771730228
#                             hamiltonian_energy: 63.14826382801352
#                       hamiltonian_energy_error: -0.012006508306534158
#                   max_hamiltonian_energy_error: -0.11544741984054951
#                                     tree_depth: 6
#                                numerical_error: false
#                                      step_size: 0.0374680731819899
#                                  nom_step_size: 0.0374680731819899
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.006691981555683051, 2.46 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  29%|█████████                      |  ETA: 0:00:23
#                                     iterations: 571
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.1
#                                        n_steps: 48
#                                      is_accept: true
#                                acceptance_rate: 0.5932398880540432
#                                    log_density: -56.42207479960642
#                             hamiltonian_energy: 61.6227101080056
#                       hamiltonian_energy_error: -0.12206830634267618
#                   max_hamiltonian_energy_error: 1261.2250061201473
#                                     tree_depth: 5
#                                numerical_error: true
#                                      step_size: 0.04362188191619923
#                                  nom_step_size: 0.04362188191619923
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.006691981555683051, 2.46 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  30%|██████████                     |  ETA: 0:00:22
#                                     iterations: 600
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.1
#                                        n_steps: 127
#                                      is_accept: true
#                                acceptance_rate: 0.9986677528239764
#                                    log_density: -56.83909267464723
#                             hamiltonian_energy: 59.34303196324183
#                       hamiltonian_energy_error: -0.005573532639289169
#                   max_hamiltonian_energy_error: -0.14187664852254755
#                                     tree_depth: 7
#                                numerical_error: false
#                                      step_size: 0.032706177362435286
#                                  nom_step_size: 0.032706177362435286
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.006691981555683051, 2.46 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  31%|██████████                     |  ETA: 0:00:21
#                                     iterations: 629
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.1
#                                        n_steps: 63
#                                      is_accept: true
#                                acceptance_rate: 0.5893186812050556
#                                    log_density: -54.494624984675674
#                             hamiltonian_energy: 60.45943669082294
#                       hamiltonian_energy_error: 0.08302696538676457
#                   max_hamiltonian_energy_error: 8.193204770958815
#                                     tree_depth: 6
#                                numerical_error: false
#                                      step_size: 0.04013098843844245
#                                  nom_step_size: 0.04013098843844245
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.006691981555683051, 2.46 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  33%|███████████                    |  ETA: 0:00:20
#                                     iterations: 651
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.1
#                                        n_steps: 511
#                                      is_accept: true
#                                acceptance_rate: 0.9999893394552445
#                                    log_density: -53.75743165386252
#                             hamiltonian_energy: 57.18120795225723
#                       hamiltonian_energy_error: -0.0034657061672618283
#                   max_hamiltonian_energy_error: -0.007679849025954866
#                                     tree_depth: 8
#                                numerical_error: false
#                                      step_size: 0.009318313483956887
#                                  nom_step_size: 0.009318313483956887
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.006691981555683051, 2.46 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  34%|███████████                    |  ETA: 0:00:20
#                                     iterations: 673
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.1
#                                        n_steps: 127
#                                      is_accept: true
#                                acceptance_rate: 0.8597828591298105
#                                    log_density: -58.083976464979074
#                             hamiltonian_energy: 63.017506393453075
#                       hamiltonian_energy_error: 0.36790332277844584
#                   max_hamiltonian_energy_error: 0.39771571255684535
#                                     tree_depth: 7
#                                numerical_error: false
#                                      step_size: 0.02014867725887469
#                                  nom_step_size: 0.02014867725887469
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.006691981555683051, 2.46 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  36%|████████████                   |  ETA: 0:00:18
#                                     iterations: 716
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.1
#                                        n_steps: 63
#                                      is_accept: true
#                                acceptance_rate: 0.9747467773443361
#                                    log_density: -60.38360472995208
#                             hamiltonian_energy: 64.21184584736488
#                       hamiltonian_energy_error: -0.037576864558062084
#                   max_hamiltonian_energy_error: 0.1178906979566392
#                                     tree_depth: 6
#                                numerical_error: false
#                                      step_size: 0.024572309972274956
#                                  nom_step_size: 0.024572309972274956
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.006691981555683051, 2.46 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  38%|████████████                   |  ETA: 0:00:17
#                                     iterations: 752
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.09
#                                        n_steps: 127
#                                      is_accept: true
#                                acceptance_rate: 0.974500312418393
#                                    log_density: -54.82124671391945
#                             hamiltonian_energy: 65.43553977032208
#                       hamiltonian_energy_error: -0.519795831979792
#                   max_hamiltonian_energy_error: -1.6812346307210788
#                                     tree_depth: 7
#                                numerical_error: false
#                                      step_size: 0.044184673162896
#                                  nom_step_size: 0.044184673162896
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.006691981555683051, 2.46 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  39%|█████████████                  |  ETA: 0:00:16
#                                     iterations: 788
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.09
#                                        n_steps: 255
#                                      is_accept: true
#                                acceptance_rate: 0.08490532381591435
#                                    log_density: -56.20206923103507
#                             hamiltonian_energy: 63.90070934833576
#                       hamiltonian_energy_error: 2.107167296069157
#                   max_hamiltonian_energy_error: 8.663536547604295
#                                     tree_depth: 7
#                                numerical_error: false
#                                      step_size: 0.032135207068329064
#                                  nom_step_size: 0.032135207068329064
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.006691981555683051, 2.46 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  41%|█████████████                  |  ETA: 0:00:15
#                                     iterations: 816
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.09
#                                        n_steps: 127
#                                      is_accept: true
#                                acceptance_rate: 0.9158840230043099
#                                    log_density: -54.658276430990455
#                             hamiltonian_energy: 60.28371719871127
#                       hamiltonian_energy_error: 0.1559774256484232
#                   max_hamiltonian_energy_error: 0.5720492131086345
#                                     tree_depth: 6
#                                numerical_error: false
#                                      step_size: 0.050945450520063856
#                                  nom_step_size: 0.050945450520063856
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.006691981555683051, 2.46 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  42%|██████████████                 |  ETA: 0:00:14
#                                     iterations: 847
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.09
#                                        n_steps: 127
#                                      is_accept: true
#                                acceptance_rate: 0.9259981068307086
#                                    log_density: -58.60682842581867
#                             hamiltonian_energy: 64.29170812395081
#                       hamiltonian_energy_error: 0.14799171572978764
#                   max_hamiltonian_energy_error: 0.5536364346559992
#                                     tree_depth: 7
#                                numerical_error: false
#                                      step_size: 0.03453983905818295
#                                  nom_step_size: 0.03453983905818295
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.006691981555683051, 2.46 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  44%|██████████████                 |  ETA: 0:00:14
#                                     iterations: 884
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.09
#                                        n_steps: 127
#                                      is_accept: true
#                                acceptance_rate: 0.9090983771054041
#                                    log_density: -56.86710503470272
#                             hamiltonian_energy: 58.79206060781953
#                       hamiltonian_energy_error: 0.11001811592734612
#                   max_hamiltonian_energy_error: 0.23777296353329547
#                                     tree_depth: 7
#                                numerical_error: false
#                                      step_size: 0.02793923438736756
#                                  nom_step_size: 0.02793923438736756
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.006691981555683051, 2.46 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  46%|███████████████                |  ETA: 0:00:13
#                                     iterations: 920
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.09
#                                        n_steps: 63
#                                      is_accept: true
#                                acceptance_rate: 0.9929411141569756
#                                    log_density: -55.02682905010863
#                             hamiltonian_energy: 57.31099257981736
#                       hamiltonian_energy_error: -0.08793118519830045
#                   max_hamiltonian_energy_error: -0.13748517204376043
#                                     tree_depth: 6
#                                numerical_error: false
#                                      step_size: 0.03261651149258248
#                                  nom_step_size: 0.03261651149258248
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.006691981555683051, 2.46 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  47%|███████████████                |  ETA: 0:00:12
#                                     iterations: 946
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.09
#                                        n_steps: 255
#                                      is_accept: true
#                                acceptance_rate: 0.9124416528014118
#                                    log_density: -56.784371526785804
#                             hamiltonian_energy: 63.12963815735756
#                       hamiltonian_energy_error: -0.10298535765146966
#                   max_hamiltonian_energy_error: 0.49555591457187376
#                                     tree_depth: 7
#                                numerical_error: false
#                                      step_size: 0.023956032278849803
#                                  nom_step_size: 0.023956032278849803
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.006691981555683051, 2.46 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  49%|████████████████               |  ETA: 0:00:12
#                                     iterations: 971
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.09
#                                        n_steps: 127
#                                      is_accept: true
#                                acceptance_rate: 0.8035934637429621
#                                    log_density: -54.57945987383549
#                             hamiltonian_energy: 59.55805778437271
#                       hamiltonian_energy_error: 0.016855597943091993
#                   max_hamiltonian_energy_error: 439.076411404105
#                                     tree_depth: 6
#                                numerical_error: false
#                                      step_size: 0.035441940181003724
#                                  nom_step_size: 0.035441940181003724
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.006466712502149981, 1.00 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  50%|████████████████               |  ETA: 0:00:11
#                                     iterations: 996
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.09
#                                        n_steps: 63
#                                      is_accept: true
#                                acceptance_rate: 1.0
#                                    log_density: -55.812742378793075
#                             hamiltonian_energy: 58.66125214754659
#                       hamiltonian_energy_error: -0.2445822661560797
#                   max_hamiltonian_energy_error: -0.49096303547744213
#                                     tree_depth: 6
#                                numerical_error: false
#                                      step_size: 0.03976984485902946
#                                  nom_step_size: 0.03976984485902946
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.006466712502149981, 1.00 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  51%|████████████████               |  ETA: 0:00:11
#                                     iterations: 1024
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.09
#                                        n_steps: 127
#                                      is_accept: true
#                                acceptance_rate: 0.9953537358273451
#                                    log_density: -57.64900320120175
#                             hamiltonian_energy: 60.5993946888905
#                       hamiltonian_energy_error: 0.026825638527419926
#                   max_hamiltonian_energy_error: -0.19844775590060948
#                                     tree_depth: 7
#                                numerical_error: false
#                                      step_size: 0.028076199113665132
#                                  nom_step_size: 0.028076199113665132
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.006466712502149981, 1.00 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  53%|█████████████████              |  ETA: 0:00:10
#                                     iterations: 1056
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.09
#                                        n_steps: 111
#                                      is_accept: true
#                                acceptance_rate: 0.9976773399526444
#                                    log_density: -58.414979009281126
#                             hamiltonian_energy: 65.28144446131546
# ...
#                             hamiltonian_energy: 62.267678710838666
#                       hamiltonian_energy_error: 0.7234272064633984
#                   max_hamiltonian_energy_error: 0.8440019117658366
#                                     tree_depth: 6
#                                numerical_error: false
#                                      step_size: 0.028076199113665132
#                                  nom_step_size: 0.028076199113665132
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.006466712502149981, 1.00 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  91%|█████████████████████████████  |  ETA: 0:00:02
#                                     iterations: 1816
#                    ratio_divergent_transitions: 0.01
#    ratio_divergent_transitions_during_adaption: 0.05
#                                        n_steps: 127
#                                      is_accept: true
#                                acceptance_rate: 0.8151089452503743
#                                    log_density: -56.88142620904662
#                             hamiltonian_energy: 63.140698938909246
#                       hamiltonian_energy_error: 0.28086067320668207
#                   max_hamiltonian_energy_error: 0.6137733791630708
#                                     tree_depth: 7
#                                numerical_error: false
#                                      step_size: 0.028076199113665132
#                                  nom_step_size: 0.028076199113665132
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.006466712502149981, 1.00 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  91%|█████████████████████████████  |  ETA: 0:00:02
#                                     iterations: 1829
#                    ratio_divergent_transitions: 0.01
#    ratio_divergent_transitions_during_adaption: 0.05
#                                        n_steps: 127
#                                      is_accept: true
#                                acceptance_rate: 0.45688141627062406
#                                    log_density: -61.91206593266812
#                             hamiltonian_energy: 67.1830366280552
#                       hamiltonian_energy_error: 1.033592345425447
#                   max_hamiltonian_energy_error: 1.9865805748569016
#                                     tree_depth: 7
#                                numerical_error: false
#                                      step_size: 0.028076199113665132
#                                  nom_step_size: 0.028076199113665132
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.006466712502149981, 1.00 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  92%|█████████████████████████████  |  ETA: 0:00:01
#                                     iterations: 1844
#                    ratio_divergent_transitions: 0.01
#    ratio_divergent_transitions_during_adaption: 0.05
#                                        n_steps: 127
#                                      is_accept: true
#                                acceptance_rate: 0.996132538459085
#                                    log_density: -54.828288586063486
#                             hamiltonian_energy: 58.32581820490152
#                       hamiltonian_energy_error: -0.00855355872929664
#                   max_hamiltonian_energy_error: -0.039473399459168945
#                                     tree_depth: 7
#                                numerical_error: false
#                                      step_size: 0.028076199113665132
#                                  nom_step_size: 0.028076199113665132
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.006466712502149981, 1.00 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  93%|█████████████████████████████  |  ETA: 0:00:01
#                                     iterations: 1858
#                    ratio_divergent_transitions: 0.01
#    ratio_divergent_transitions_during_adaption: 0.05
#                                        n_steps: 127
#                                      is_accept: true
#                                acceptance_rate: 1.0
#                                    log_density: -57.4162462721783
#                             hamiltonian_energy: 66.99356498374016
#                       hamiltonian_energy_error: -0.28245006183350085
#                   max_hamiltonian_energy_error: -0.8905948551580991
#                                     tree_depth: 6
#                                numerical_error: false
#                                      step_size: 0.028076199113665132
#                                  nom_step_size: 0.028076199113665132
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.006466712502149981, 1.00 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  94%|██████████████████████████████ |  ETA: 0:00:01
#                                     iterations: 1875
#                    ratio_divergent_transitions: 0.01
#    ratio_divergent_transitions_during_adaption: 0.05
#                                        n_steps: 127
#                                      is_accept: true
#                                acceptance_rate: 0.9828705243034578
#                                    log_density: -55.05822186802337
#                             hamiltonian_energy: 60.2532006549816
#                       hamiltonian_energy_error: -0.21374407192162437
#                   max_hamiltonian_energy_error: -0.4269541735963003
#                                     tree_depth: 7
#                                numerical_error: false
#                                      step_size: 0.028076199113665132
#                                  nom_step_size: 0.028076199113665132
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.006466712502149981, 1.00 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  95%|██████████████████████████████ |  ETA: 0:00:01
#                                     iterations: 1891
#                    ratio_divergent_transitions: 0.01
#    ratio_divergent_transitions_during_adaption: 0.05
#                                        n_steps: 255
#                                      is_accept: true
#                                acceptance_rate: 0.9556756900006688
#                                    log_density: -59.16890432002336
#                             hamiltonian_energy: 63.70934987509868
#                       hamiltonian_energy_error: -0.013800099926683629
#                   max_hamiltonian_energy_error: 26.26983556429063
#                                     tree_depth: 7
#                                numerical_error: false
#                                      step_size: 0.028076199113665132
#                                  nom_step_size: 0.028076199113665132
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.006466712502149981, 1.00 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  95%|██████████████████████████████ |  ETA: 0:00:01
#                                     iterations: 1906
#                    ratio_divergent_transitions: 0.01
#    ratio_divergent_transitions_during_adaption: 0.05
#                                        n_steps: 511
#                                      is_accept: true
#                                acceptance_rate: 0.28349556999166653
#                                    log_density: -56.9842379235756
#                             hamiltonian_energy: 62.15639822746783
#                       hamiltonian_energy_error: 0.3559196671145912
#                   max_hamiltonian_energy_error: 24.348319656168172
#                                     tree_depth: 8
#                                numerical_error: false
#                                      step_size: 0.028076199113665132
#                                  nom_step_size: 0.028076199113665132
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.006466712502149981, 1.00 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  96%|██████████████████████████████ |  ETA: 0:00:01
#                                     iterations: 1918
#                    ratio_divergent_transitions: 0.01
#    ratio_divergent_transitions_during_adaption: 0.05
#                                        n_steps: 255
#                                      is_accept: true
#                                acceptance_rate: 0.9324448203426309
#                                    log_density: -58.381344227380374
#                             hamiltonian_energy: 68.33006362141616
#                       hamiltonian_energy_error: -0.6530807341640212
#                   max_hamiltonian_energy_error: 2.179509028497648
#                                     tree_depth: 7
#                                numerical_error: false
#                                      step_size: 0.028076199113665132
#                                  nom_step_size: 0.028076199113665132
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.006466712502149981, 1.00 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  97%|██████████████████████████████ |  ETA: 0:00:01
#                                     iterations: 1931
#                    ratio_divergent_transitions: 0.01
#    ratio_divergent_transitions_during_adaption: 0.05
#                                        n_steps: 127
#                                      is_accept: true
#                                acceptance_rate: 0.9946504435296786
#                                    log_density: -56.915715368283244
#                             hamiltonian_energy: 61.23879196587666
#                       hamiltonian_energy_error: -0.05194388867822397
#                   max_hamiltonian_energy_error: -0.1892286589636356
#                                     tree_depth: 7
#                                numerical_error: false
#                                      step_size: 0.028076199113665132
#                                  nom_step_size: 0.028076199113665132
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.006466712502149981, 1.00 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  97%|███████████████████████████████|  ETA: 0:00:01
#                                     iterations: 1946
#                    ratio_divergent_transitions: 0.01
#    ratio_divergent_transitions_during_adaption: 0.05
#                                        n_steps: 255
#                                      is_accept: true
#                                acceptance_rate: 0.9194457135332351
#                                    log_density: -57.52816555616165
#                             hamiltonian_energy: 62.80363437569882
#                       hamiltonian_energy_error: 0.03158770205493511
#                   max_hamiltonian_energy_error: 0.35423068243559186
#                                     tree_depth: 7
#                                numerical_error: false
#                                      step_size: 0.028076199113665132
#                                  nom_step_size: 0.028076199113665132
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.006466712502149981, 1.00 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  98%|███████████████████████████████|  ETA: 0:00:00
#                                     iterations: 1961
#                    ratio_divergent_transitions: 0.01
#    ratio_divergent_transitions_during_adaption: 0.05
#                                        n_steps: 191
#                                      is_accept: true
#                                acceptance_rate: 0.8805301756848356
#                                    log_density: -57.1327262989073
#                             hamiltonian_energy: 65.60996669897749
#                       hamiltonian_energy_error: 0.019141628770782404
#                   max_hamiltonian_energy_error: 0.4190286637528402
#                                     tree_depth: 7
#                                numerical_error: false
#                                      step_size: 0.028076199113665132
#                                  nom_step_size: 0.028076199113665132
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.006466712502149981, 1.00 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  99%|███████████████████████████████|  ETA: 0:00:00
#                                     iterations: 1977
#                    ratio_divergent_transitions: 0.01
#    ratio_divergent_transitions_during_adaption: 0.05
#                                        n_steps: 127
#                                      is_accept: true
#                                acceptance_rate: 0.9747816146578749
#                                    log_density: -57.08527203412781
#                             hamiltonian_energy: 60.95628032974027
#                       hamiltonian_energy_error: -0.08573785444275472
#                   max_hamiltonian_energy_error: -0.6091444917466688
#                                     tree_depth: 7
#                                numerical_error: false
#                                      step_size: 0.028076199113665132
#                                  nom_step_size: 0.028076199113665132
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.006466712502149981, 1.00 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  99%|███████████████████████████████|  ETA: 0:00:00
#                                     iterations: 1996
#                    ratio_divergent_transitions: 0.01
#    ratio_divergent_transitions_during_adaption: 0.05
#                                        n_steps: 127
#                                      is_accept: true
#                                acceptance_rate: 0.90202213936168
#                                    log_density: -58.219260247685234
#                             hamiltonian_energy: 66.77293573332885
#                       hamiltonian_energy_error: 0.3657676813419499
#                   max_hamiltonian_energy_error: -1.6913185308696939
#                                     tree_depth: 6
#                                numerical_error: false
#                                      step_size: 0.028076199113665132
#                                  nom_step_size: 0.028076199113665132
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.006466712502149981, 1.00 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling 100%|███████████████████████████████| Time: 0:00:19
#                                     iterations: 2000
#                    ratio_divergent_transitions: 0.01
#    ratio_divergent_transitions_during_adaption: 0.04
#                                        n_steps: 63
#                                      is_accept: true
#                                acceptance_rate: 0.9439219736828696
#                                    log_density: -53.96911504897251
#                             hamiltonian_energy: 56.309771582659884
#                       hamiltonian_energy_error: 0.10878138240180846
#                   max_hamiltonian_energy_error: 0.14794528608889834
#                                     tree_depth: 6
#                                numerical_error: false
#                                      step_size: 0.028076199113665132
#                                  nom_step_size: 0.028076199113665132
#                                       is_adapt: false
#                                    mass_matrix: DenseEuclideanMetric(diag=[0.006466712502149981, 1.00 ...])
# [ Info: Sampling compete. Building chains.
# Sampling report for chain:
# mean_accept                 = 0.825962113389252
# ratio_divergent_transitions = 0.02
# mean_tree_depth             = 6.715
# max_tree_depth_frac         = 0.0
# total_steps                 = 302102
# μs/step                     = 71.7

# %% [markdown]
# **Long runtimes indiciate an error in your model**
#
# The orbit fitting should take <30 s for this example. If you find it takes much longer on your code, double check the model and priors. Is the epoch you specified for `tperi` the same as your data?
#
# **Numerical errors indicate a problem with sampling**
# If you see a report that numerical errors were encountered during sampling, the results may not be statistically valid. You could re-try sampling, or investigate your model for errors.

# %% [markdown]
# We can now display our results

# %%
chain
# Out:
# Chains MCMC chain (1000×28×1 Array{Float64, 3}):
#
# Iterations        = 1:1:1000
# Number of chains  = 1
# Samples per chain = 1000
# Wall duration     = 21.68 seconds
# Compute duration  = 21.68 seconds
# parameters        = M, plx, b_a, b_e, b_i, b_ωy, b_ωx, b_Ωy, b_Ωx, b_θy, b_θx, b_ω, b_Ω, b_θ, b_tp
# internals         = n_steps, is_accept, acceptance_rate, hamiltonian_energy, hamiltonian_energy_error, max_hamiltonian_energy_error, tree_depth, numerical_error, step_size, nom_step_size, is_adapt, loglike, logpost, tree_depth, numerical_error
#
# Summary Statistics
#   parameters         mean         std       mcse   ess_bulk   ess_tail      rh ⋯
#       Symbol      Float64     Float64    Float64    Float64    Float64   Float ⋯
#
#            M       1.1945      0.0959     0.0041   570.2002   500.7792    1.00 ⋯
#          plx      50.0004      0.0198     0.0007   891.9757   518.8118    1.00 ⋯
#          b_a      13.0013      4.0319     0.4004   109.8668   179.8020    1.00 ⋯
#          b_e       0.1580      0.1175     0.0120    98.3081   198.1265    1.00 ⋯
#          b_i       0.6919      0.1636     0.0147   122.8986   224.1464    1.00 ⋯
#         b_ωy       0.0093      0.7260     0.0681   148.5396   522.4149    1.00 ⋯
#         b_ωx      -0.0200      0.7048     0.0599   167.0340   456.0307    1.00 ⋯
#         b_Ωy      -0.0214      0.7867     0.2991     8.0947   286.1703    1.20 ⋯
#         b_Ωx       0.0293      0.6346     0.1850    13.5299   136.1762    1.08 ⋯
#         b_θy      -0.1319      0.0176     0.0007   647.7344   573.6430    1.00 ⋯
#         b_θx      -0.9961      0.0952     0.0038   684.4277   278.5139    1.00 ⋯
#          b_ω      -0.1727      1.8000     0.1315   243.9848   342.7297    1.00 ⋯
#          b_Ω      -0.5951      1.7847     0.4641    24.6823   115.8411    1.21 ⋯
#          b_θ      -1.7025      0.0127     0.0005   665.4563   579.6001    1.00 ⋯
#         b_tp   41317.6575   9030.2733   882.9365   188.9127   183.0705    1.01 ⋯
#                                                                2 columns omitted
#
# Quantiles
#   parameters         2.5%        25.0%        50.0%        75.0%        97.5%
#       Symbol      Float64      Float64      Float64      Float64      Float64
#
#            M       1.0042       1.1340       1.1994       1.2534       1.3791
#          plx      49.9637      49.9867      50.0000      50.0141      50.0390
#          b_a       8.5302      10.3167      11.9248      14.4772      22.4749
#          b_e       0.0076       0.0591       0.1314       0.2328       0.4236
#          b_i       0.3761       0.5815       0.6851       0.8070       1.0117
#         b_ωy      -1.0598      -0.6937       0.0017       0.7288       1.0822
#         b_ωx      -1.0600      -0.7205      -0.0354       0.6719       1.0703
#         b_Ωy      -1.0966      -0.8214      -0.0541       0.8096       1.0809
#         b_Ωx      -1.0647      -0.4980       0.0317       0.5788       1.0345
#         b_θy      -0.1685      -0.1445      -0.1300      -0.1195      -0.0994
#         b_θx      -1.2050      -1.0552      -0.9914      -0.9284      -0.8268
#          b_ω      -2.9980      -1.9191      -0.1010       1.2257       2.9568
#          b_Ω      -3.0197      -2.4896       0.0626       0.7301       2.6168
#          b_θ      -1.7277      -1.7110      -1.7025      -1.6936      -1.6789
#         b_tp   19845.0798   38416.4598   43982.7775   46688.8033   49539.1541

# %% [markdown]
# ###### If you wish to save this summary table to a text file, you can convert it to a string like so:

# %%
summary_str = repr(chain)

# %% [markdown]
# The chain itself can be saved to a FITS table like so:

# %%
octo.savechain("mychain.fits", chain)
# Out:
# ---------------------------------------------------------------------------
# JuliaError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 octo.savechain("mychain.fits", chain)
#
# File ~\.julia\packages\PythonCall\Nr75f\src\JlWrap\any.jl:258, in __call__(self, *args, **kwargs)
#     256     return ValueBase.__dir__(self) + self._jl_callmethod($(pyjl_methodnum(pyjlany_dir)))
#     257 def __call__(self, *args, **kwargs):
# --> 258     return self._jl_callmethod($(pyjl_methodnum(pyjlany_call)), args, kwargs)
#     259 def __bool__(self):
#     260     return True
#
# JuliaError: BoundsError: attempt to access 0-element LinearIndices{1, Tuple{Base.OneTo{Int64}}} at index [1]
# Stacktrace:
#   [1] throw_boundserror(A::LinearIndices{1, Tuple{Base.OneTo{Int64}}}, I::Tuple{Int64})
#     @ Base .\abstractarray.jl:737
#   [2] checkbounds
#     @ .\abstractarray.jl:702 [inlined]
#   [3] getindex
#     @ .\indices.jl:510 [inlined]
#   [4] _getindex
#     @ .\abstractarray.jl:1318 [inlined]
#   [5] getindex
#     @ .\abstractarray.jl:1290 [inlined]
#   [6] check_data_bounds
#     @ C:\Users\macke\.julia\packages\CFITSIO\Eetmr\src\CFITSIO.jl:3009 [inlined]
#   [7] fits_write_pix(f::CFITSIO.FITSFile, fpixel::Tuple{Int64}, nelements::Int64, data::Vector{Float64})
#     @ CFITSIO C:\Users\macke\.julia\packages\CFITSIO\Eetmr\src\CFITSIO.jl:3119
#   [8] fits_write_pix
#     @ C:\Users\macke\.julia\packages\CFITSIO\Eetmr\src\CFITSIO.jl:3141 [inlined]
#   [9] write(f::FITSIO.FITS, data::Vector{Float64}; header::FITSIO.FITSHeader, name::Nothing, ver::Nothing)
#     @ FITSIO C:\Users\macke\.julia\packages\FITSIO\VMmjb\src\image.jl:374
#  [10] (::Octofitter.var"#249#253"{Chains{Float64, AxisArrays.AxisArray{Float64, 3, Array{Float64, 3}, Tuple{AxisArrays.Axis{:iter, StepRange{Int64, Int64}}, AxisArrays.Axis{:var, Vector{Symbol}}, AxisArrays.Axis{:chain, UnitRange{Int64}}}}, Missing, @NamedTuple{parameters::Vector{Symbol}, internals::Vector{Symbol}}, @NamedTuple{start_time::Vector{Float64}, stop_time::Vector{Float64}, samples_transformed::Vector{Vector{Float64}}, adaptor::AdvancedHMC.Adaptation.StanHMCAdaptor{AdvancedHMC.Adaptation.WelfordCov{Float64}, AdvancedHMC.Adaptation.NesterovDualAveraging{Float64}}, initial_metric::AdvancedHMC.DenseEuclideanMetric{Float64, Vector{Float64}, Matrix{Float64}, LinearAlgebra.UpperTriangular{Float64, Matrix{Float64}}}, model_name::Symbol}}, Table{@NamedTuple{iteration::Int64, chain::Int64, n_steps::Float64, is_accept::Float64, acceptance_rate::Float64, hamiltonian_energy::Float64, hamiltonian_energy_error::Float64, max_hamiltonian_energy_error::Float64, tree_depth::Float64, numerical_error::Float64, step_size::Float64, nom_step_size::Float64, is_adapt::Float64, loglike::Float64, logpost::Float64, M::Float64, plx::Float64, b_a::Float64, b_e::Float64, b_i::Float64, b_ωy::Float64, b_ωx::Float64, b_Ωy::Float64, b_Ωx::Float64, b_θy::Float64, b_θx::Float64, b_ω::Float64, b_Ω::Float64, b_θ::Float64, b_tp::Float64}, 1, @NamedTuple{iteration::Vector{Int64}, chain::Vector{Int64}, n_steps::Base.ReshapedArray{Float64, 1, AxisArrays.AxisMatrix{Float64, Matrix{Float64}, Tuple{AxisArrays.Axis{:iter, StepRange{Int64, Int64}}, AxisArrays.Axis{:chain, UnitRange{Int64}}}}, Tuple{}}, is_accept::Base.ReshapedArray{Float64, 1, AxisArrays.AxisMatrix{Float64, Matrix{Float64}, Tuple{AxisArrays.Axis{:iter, StepRange{Int64, Int64}}, AxisArrays.Axis{:chain, UnitRange{Int64}}}}, Tuple{}}, acceptance_rate::Base.ReshapedArray{Float64, 1, AxisArrays.AxisMatrix{Float64, Matrix{Float64}, Tuple{AxisArrays.Axis{:iter, StepRange{Int64, Int64}}, AxisArrays.Axis{:chain, UnitRange{Int64}}}}, Tuple{}}, hamiltonian_energy::Base.ReshapedArray{Float64, 1, AxisArrays.AxisMatrix{Float64, Matrix{Float64}, Tuple{AxisArrays.Axis{:iter, StepRange{Int64, Int64}}, AxisArrays.Axis{:chain, UnitRange{Int64}}}}, Tuple{}}, hamiltonian_energy_error::Base.ReshapedArray{Float64, 1, AxisArrays.AxisMatrix{Float64, Matrix{Float64}, Tuple{AxisArrays.Axis{:iter, StepRange{Int64, Int64}}, AxisArrays.Axis{:chain, UnitRange{Int64}}}}, Tuple{}}, max_hamiltonian_energy_error::Base.ReshapedArray{Float64, 1, AxisArrays.AxisMatrix{Float64, Matrix{Float64}, Tuple{AxisArrays.Axis{:iter, StepRange{Int64, Int64}}, AxisArrays.Axis{:chain, UnitRange{Int64}}}}, Tuple{}}, tree_depth::Base.ReshapedArray{Float64, 1, AxisArrays.AxisMatrix{Float64, Matrix{Float64}, Tuple{AxisArrays.Axis{:iter, StepRange{Int64, Int64}}, AxisArrays.Axis{:chain, UnitRange{Int64}}}}, Tuple{}}, numerical_error::Base.ReshapedArray{Float64, 1, AxisArrays.AxisMatrix{Float64, Matrix{Float64}, Tuple{AxisArrays.Axis{:iter, StepRange{Int64, Int64}}, AxisArrays.Axis{:chain, UnitRange{Int64}}}}, Tuple{}}, step_size::Base.ReshapedArray{Float64, 1, AxisArrays.AxisMatrix{Float64, Matrix{Float64}, Tuple{AxisArrays.Axis{:iter, StepRange{Int64, Int64}}, AxisArrays.Axis{:chain, UnitRange{Int64}}}}, Tuple{}}, nom_step_size::Base.ReshapedArray{Float64, 1, AxisArrays.AxisMatrix{Float64, Matrix{Float64}, Tuple{AxisArrays.Axis{:iter, StepRange{Int64, Int64}}, AxisArrays.Axis{:chain, UnitRange{Int64}}}}, Tuple{}}, is_adapt::Base.ReshapedArray{Float64, 1, AxisArrays.AxisMatrix{Float64, Matrix{Float64}, Tuple{AxisArrays.Axis{:iter, StepRange{Int64, Int64}}, AxisArrays.Axis{:chain, UnitRange{Int64}}}}, Tuple{}}, loglike::Base.ReshapedArray{Float64, 1, AxisArrays.AxisMatrix{Float64, Matrix{Float64}, Tuple{AxisArrays.Axis{:iter, StepRange{Int64, Int64}}, AxisArrays.Axis{:chain, UnitRange{Int64}}}}, Tuple{}}, logpost::Base.ReshapedArray{Float64, 1, AxisArrays.AxisMatrix{Float64, Matrix{Float64}, Tuple{AxisArrays.Axis{:iter, StepRange{Int64, Int64}}, AxisArra ...
#     @ Octofitter C:\Users\macke\.julia\packages\Octofitter\3mclS\src\io.jl:49
#  [11] FITSIO.FITS(::Octofitter.var"#249#253"{Chains{Float64, AxisArrays.AxisArray{Float64, 3, Array{Float64, 3}, Tuple{AxisArrays.Axis{:iter, StepRange{Int64, Int64}}, AxisArrays.Axis{:var, Vector{Symbol}}, AxisArrays.Axis{:chain, UnitRange{Int64}}}}, Missing, @NamedTuple{parameters::Vector{Symbol}, internals::Vector{Symbol}}, @NamedTuple{start_time::Vector{Float64}, stop_time::Vector{Float64}, samples_transformed::Vector{Vector{Float64}}, adaptor::AdvancedHMC.Adaptation.StanHMCAdaptor{AdvancedHMC.Adaptation.WelfordCov{Float64}, AdvancedHMC.Adaptation.NesterovDualAveraging{Float64}}, initial_metric::AdvancedHMC.DenseEuclideanMetric{Float64, Vector{Float64}, Matrix{Float64}, LinearAlgebra.UpperTriangular{Float64, Matrix{Float64}}}, model_name::Symbol}}, Table{@NamedTuple{iteration::Int64, chain::Int64, n_steps::Float64, is_accept::Float64, acceptance_rate::Float64, hamiltonian_energy::Float64, hamiltonian_energy_error::Float64, max_hamiltonian_energy_error::Float64, tree_depth::Float64, numerical_error::Float64, step_size::Float64, nom_step_size::Float64, is_adapt::Float64, loglike::Float64, logpost::Float64, M::Float64, plx::Float64, b_a::Float64, b_e::Float64, b_i::Float64, b_ωy::Float64, b_ωx::Float64, b_Ωy::Float64, b_Ωx::Float64, b_θy::Float64, b_θx::Float64, b_ω::Float64, b_Ω::Float64, b_θ::Float64, b_tp::Float64}, 1, @NamedTuple{iteration::Vector{Int64}, chain::Vector{Int64}, n_steps::Base.ReshapedArray{Float64, 1, AxisArrays.AxisMatrix{Float64, Matrix{Float64}, Tuple{AxisArrays.Axis{:iter, StepRange{Int64, Int64}}, AxisArrays.Axis{:chain, UnitRange{Int64}}}}, Tuple{}}, is_accept::Base.ReshapedArray{Float64, 1, AxisArrays.AxisMatrix{Float64, Matrix{Float64}, Tuple{AxisArrays.Axis{:iter, StepRange{Int64, Int64}}, AxisArrays.Axis{:chain, UnitRange{Int64}}}}, Tuple{}}, acceptance_rate::Base.ReshapedArray{Float64, 1, AxisArrays.AxisMatrix{Float64, Matrix{Float64}, Tuple{AxisArrays.Axis{:iter, StepRange{Int64, Int64}}, AxisArrays.Axis{:chain, UnitRange{Int64}}}}, Tuple{}}, hamiltonian_energy::Base.ReshapedArray{Float64, 1, AxisArrays.AxisMatrix{Float64, Matrix{Float64}, Tuple{AxisArrays.Axis{:iter, StepRange{Int64, Int64}}, AxisArrays.Axis{:chain, UnitRange{Int64}}}}, Tuple{}}, hamiltonian_energy_error::Base.ReshapedArray{Float64, 1, AxisArrays.AxisMatrix{Float64, Matrix{Float64}, Tuple{AxisArrays.Axis{:iter, StepRange{Int64, Int64}}, AxisArrays.Axis{:chain, UnitRange{Int64}}}}, Tuple{}}, max_hamiltonian_energy_error::Base.ReshapedArray{Float64, 1, AxisArrays.AxisMatrix{Float64, Matrix{Float64}, Tuple{AxisArrays.Axis{:iter, StepRange{Int64, Int64}}, AxisArrays.Axis{:chain, UnitRange{Int64}}}}, Tuple{}}, tree_depth::Base.ReshapedArray{Float64, 1, AxisArrays.AxisMatrix{Float64, Matrix{Float64}, Tuple{AxisArrays.Axis{:iter, StepRange{Int64, Int64}}, AxisArrays.Axis{:chain, UnitRange{Int64}}}}, Tuple{}}, numerical_error::Base.ReshapedArray{Float64, 1, AxisArrays.AxisMatrix{Float64, Matrix{Float64}, Tuple{AxisArrays.Axis{:iter, StepRange{Int64, Int64}}, AxisArrays.Axis{:chain, UnitRange{Int64}}}}, Tuple{}}, step_size::Base.ReshapedArray{Float64, 1, AxisArrays.AxisMatrix{Float64, Matrix{Float64}, Tuple{AxisArrays.Axis{:iter, StepRange{Int64, Int64}}, AxisArrays.Axis{:chain, UnitRange{Int64}}}}, Tuple{}}, nom_step_size::Base.ReshapedArray{Float64, 1, AxisArrays.AxisMatrix{Float64, Matrix{Float64}, Tuple{AxisArrays.Axis{:iter, StepRange{Int64, Int64}}, AxisArrays.Axis{:chain, UnitRange{Int64}}}}, Tuple{}}, is_adapt::Base.ReshapedArray{Float64, 1, AxisArrays.AxisMatrix{Float64, Matrix{Float64}, Tuple{AxisArrays.Axis{:iter, StepRange{Int64, Int64}}, AxisArrays.Axis{:chain, UnitRange{Int64}}}}, Tuple{}}, loglike::Base.ReshapedArray{Float64, 1, AxisArrays.AxisMatrix{Float64, Matrix{Float64}, Tuple{AxisArrays.Axis{:iter, StepRange{Int64, Int64}}, AxisArrays.Axis{:chain, UnitRange{Int64}}}}, Tuple{}}, logpost::Base.ReshapedArray{Float64, 1, AxisArrays.AxisMatrix{Float64, Matrix{Float64}, Tuple{AxisArrays.Axis{:iter, StepRange{Int64, Int64} ...
#     @ FITSIO C:\Users\macke\.julia\packages\FITSIO\VMmjb\src\FITSIO.jl:212
#  [12] FITSIO.FITS(::Function, ::String, ::Vararg{String})
#     @ FITSIO C:\Users\macke\.julia\packages\FITSIO\VMmjb\src\FITSIO.jl:209
#  [13] savechain(fname::String, chain::Chains{Float64, AxisArrays.AxisArray{Float64, 3, Array{Float64, 3}, Tuple{AxisArrays.Axis{:iter, StepRange{Int64, Int64}}, AxisArrays.Axis{:var, Vector{Symbol}}, AxisArrays.Axis{:chain, UnitRange{Int64}}}}, Missing, @NamedTuple{parameters::Vector{Symbol}, internals::Vector{Symbol}}, @NamedTuple{start_time::Vector{Float64}, stop_time::Vector{Float64}, samples_transformed::Vector{Vector{Float64}}, adaptor::AdvancedHMC.Adaptation.StanHMCAdaptor{AdvancedHMC.Adaptation.WelfordCov{Float64}, AdvancedHMC.Adaptation.NesterovDualAveraging{Float64}}, initial_metric::AdvancedHMC.DenseEuclideanMetric{Float64, Vector{Float64}, Matrix{Float64}, LinearAlgebra.UpperTriangular{Float64, Matrix{Float64}}}, model_name::Symbol}})
#     @ Octofitter C:\Users\macke\.julia\packages\Octofitter\3mclS\src\io.jl:18
#  [14] pyjlany_call(self::typeof(Octofitter.savechain), args_::Py, kwargs_::Py)
#     @ PythonCall.JlWrap C:\Users\macke\.julia\packages\PythonCall\Nr75f\src\JlWrap\any.jl:43
#  [15] _pyjl_callmethod(f::Any, self_::Ptr{PythonCall.C.PyObject}, args_::Ptr{PythonCall.C.PyObject}, nargs::Int64)
#     @ PythonCall.JlWrap C:\Users\macke\.julia\packages\PythonCall\Nr75f\src\JlWrap\base.jl:73
#  [16] _pyjl_callmethod(o::Ptr{PythonCall.C.PyObject}, args::Ptr{PythonCall.C.PyObject})
#     @ PythonCall.JlWrap.Cjl C:\Users\macke\.julia\packages\PythonCall\Nr75f\src\JlWrap\C.jl:63

# %% [markdown]
# And restored from a FITS table like so:

# %%
restored_chain = octo.loadchain("mychain.fits")
# Out:
# ---------------------------------------------------------------------------
# JuliaError                                Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 restored_chain = octo.loadchain("mychain.fits")
#
# File ~\.julia\packages\PythonCall\Nr75f\src\JlWrap\any.jl:258, in __call__(self, *args, **kwargs)
#     256     return ValueBase.__dir__(self) + self._jl_callmethod($(pyjl_methodnum(pyjlany_dir)))
#     257 def __call__(self, *args, **kwargs):
# --> 258     return self._jl_callmethod($(pyjl_methodnum(pyjlany_call)), args, kwargs)
#     259 def __bool__(self):
#     260     return True
#
# JuliaError: CFITSIO has encountered an error while processing mychain.fits. Error code 104: could not open the named file
# Detailed error message follows:
# Warning: the following keyword does not conform to the HIERARCH convention
# HIERARCH start_time = 'ARRAY   ' / chain-info
# Warning: the following keyword does not conform to the HIERARCH convention
# HIERARCH stop_time = 'ARRAY   ' / chain-info
# Warning: the following keyword does not conform to the HIERARCH convention
# HIERARCH samples_transformed= '[[0.2639469056678519, 3.9125406633333726, -4.166'
# Warning: the following keyword does not conform to the HIERARCH convention
# HIERARCH initial_metric= 'DenseEuclideanMetric(diag=[0.003017770291167465, 1.31'
# Warning: the following keyword does not conform to the HIERARCH convention
# HIERARCH model_name = 'HIP100123' / chain-info
# Warning: the following keyword does not conform to the HIERARCH convention
# HIERARCH start_time_1 = 1752240763.189 / chain-info
# Warning: the following keyword does not conform to the HIERARCH convention
# HIERARCH stop_time_1 = 1752240784.864 / chain-info
# failed to find or open the following file: (ffopen)
# mychain.fits
#
# Stacktrace:
#   [1] fits_assert_ok
#     @ C:\Users\macke\.julia\packages\CFITSIO\Eetmr\src\CFITSIO.jl:342 [inlined]
#   [2] fits_open_file(filename::String, mode::Int64)
#     @ CFITSIO C:\Users\macke\.julia\packages\CFITSIO\Eetmr\src\CFITSIO.jl:668
#   [3] FITSIO.FITS(filename::String, mode::String; extendedparser::Bool)
#     @ FITSIO C:\Users\macke\.julia\packages\FITSIO\VMmjb\src\FITSIO.jl:186
#   [4] FITS (repeats 2 times)
#     @ C:\Users\macke\.julia\packages\FITSIO\VMmjb\src\FITSIO.jl:183 [inlined]
#   [5] FITSIO.FITS(f::Octofitter.var"#258#260", args::String; kwargs::@Kwargs{})
#     @ FITSIO C:\Users\macke\.julia\packages\FITSIO\VMmjb\src\FITSIO.jl:210
#   [6] FITS
#     @ C:\Users\macke\.julia\packages\FITSIO\VMmjb\src\FITSIO.jl:209 [inlined]
#   [7] loadchain(fname::String)
#     @ Octofitter C:\Users\macke\.julia\packages\Octofitter\3mclS\src\io.jl:79
#   [8] pyjlany_call(self::typeof(Octofitter.loadchain), args_::Py, kwargs_::Py)
#     @ PythonCall.JlWrap C:\Users\macke\.julia\packages\PythonCall\Nr75f\src\JlWrap\any.jl:43
#   [9] _pyjl_callmethod(f::Any, self_::Ptr{PythonCall.C.PyObject}, args_::Ptr{PythonCall.C.PyObject}, nargs::Int64)
#     @ PythonCall.JlWrap C:\Users\macke\.julia\packages\PythonCall\Nr75f\src\JlWrap\base.jl:73
#  [10] _pyjl_callmethod(o::Ptr{PythonCall.C.PyObject}, args::Ptr{PythonCall.C.PyObject})
#     @ PythonCall.JlWrap.Cjl C:\Users\macke\.julia\packages\PythonCall\Nr75f\src\JlWrap\C.jl:63

# %% [markdown]
# ## Plotting

# %% [markdown]
# Use the `octoplot` function to generate plots. You can use keyword arguments (see documentation) to control which output panels appear. By default, they will be chosen automatically based on the kinds of data likelihoods you supply to the model.
#
# The output is automatically saved to a PNG file in your current folder, with a name based on the name of the System you created.
# You can also customize this using the `fname` argument (see docs for more details). You can change the image format (eg to PDF) by changing the file name extension.

# %%
octo.octoplot(model,chain)
# Out:
# ┌ Info: You can control the panels included by `octoplot` by passing keyword arguments. Currently selected:
# │   show_astrom = true
# │   show_physical_orbit = false
# │   show_astrom_time = true
# │   show_hgca = false
# │   show_mass = false
# │   show_rv = false
# │   show_relative_rv = false
# └   show_hipparcos = false
# [ Info: pass true or false for each of these arguments to suppress this message.

# %% [markdown]
# The `octocorner` function makes a corner plot using the `pairplots` library. Optionaly set `small=False` to see all variables. The PNG file will automatically be saved to your current directory using a file name based on the System name you provided, or you can override using the `fname` argument (and change the output image format eg to pdf).
# The documentation page lists additional arguments that can be used to control the appearance.

# %%
octo.octocorner(model,chain,small=True)

# %% [markdown]
# ## Fit Relative Astrometry and HGCA
#
# Octofitter.jl supports fitting orbit models to astrometric motion in the form of GAIA-Hipparcos proper motion anomaly (HGCA; [https://arxiv.org/abs/2105.11662](https://arxiv.org/abs/2105.11662)).
# These data points are calculated by finding the difference between a long term proper motion of a star between the Hipparcos and GAIA catalogs, and their proper motion calculated within the windows of each catalog. This gives four data points that can constrain the dynamical mass & orbits of planetary companions (assuming we subtract out the net trend).
#
# If your star of interest is in the HGCA, all you need is it's GAIA DR3 ID number. You can find this number by searching for your target on [SIMBAD](http://simbad.cds.unistra.fr).
#
# For this tutorial, we will examine the star and companion [HD 91312 A & B](https://arxiv.org/abs/2109.12124) discovered by SCExAO. We will use their published astrometry and proper motion anomaly extracted from the HGCA.
#
# The first step is to find the GAIA source ID for your object. For HD 91312, SIMBAD tells us the GAIA DR3 ID is `756291174721509376`.
#
# You can add a Hipparcos-GAIA proper motion anomally likelihood function by following these examples. You will need to add a `mass` variable to the planet, and `pmra` and `pmdec` (mas/yr) parameters to the system.

# %%
astrom_like = octo.PlanetRelAstromLikelihood(
    # MJD
    epoch = [57737.0,57824.0,57825.0,58157.0,58450.0,58467.0],
    # delta RA, milliarcseconds (East is positive)
    ra = [133.0, 126.0, 127.0, 83.0, 58.0, 56.0],
    # delta DEC, milliarcseconds (North is positive)
    dec = [-174.0, -176.0, -172.0, -133.0, -122.0, -104.0],
    # Uncertainty on RA, milliarcseconds
    σ_ra = [7.0, 4.0, 4.0, 10.0, 10.0, 8.0],
    # Uncertainty on DEC, milliarcseconds
	σ_dec = [7.0, 4.0, 4.0, 10.0, 20.0, 8.0],
    # Corelation between RA and DEC uncertainties
	cor= [0,0,0,0,0,0]
)
    

planet_b = octo.Planet(
    name="b",
    basis="Visual{KepOrbit}",
    priors=
    """            
        a ~ LogUniform(0.1, 500)
        e ~ Uniform(0.0, 0.99)
        i ~ Sine()
        ω ~ UniformCircular()
        Ω ~ UniformCircular()
        θ ~ UniformCircular()
        tp = θ_at_epoch_to_tperi(system,b,50000) # use MJD epoch of your data here!!
        mass ~ LogUniform(1, 1000)
    """,
    likelihoods=[astrom_like]
)

hgca_like = octo.HGCALikelihood(gaia_id=756291174721509376)
# The name of your system determines the output file names
sys = octo.System(
    name="HIP100123_with_pma",
    priors=
    """
        M ~ truncated(Normal(1.6, 0.1), lower=0)
        plx ~ gaia_plx(gaia_id=756291174721509376)
        pmra ~ Normal(0,1000)
        pmdec ~ Normal(0,1000)
    """,
    likelihoods=[hgca_like],
    companions=[planet_b]
)
model = octo.LogDensityModel(sys)

# %% [markdown]
# We can now fit the model using `octo.octofit` as before

# %%
chain = octo.octofit(model)

# %%
octo.octoplot(model,chain)

# %% [markdown]
# The above will work well if you have decent orbital coverage. If you don't (like in this case), an HGCA posterior is could bemulti-modal.
# To sample from a multi-modal, posterior, try using Pigeons non-reversible parallel tempered sampling. This is more robust, but somewhat slower.
#
# We can do that as follows:

# %%
chain, pt = octo.octofit_pigeons(model, n_rounds=6)

# %% [markdown]
# The number of iterations will be `2**n_rounds`, .i.e n_rounds=10 will generate 1024 posterior samples. The default number of chains used for tempering is 16, with an additional 16 "variational" chains.

# %% [markdown]
# Unlike HMC (`octo.octofit`), pigeons tempered sampling (`octo.octofit_pigeons`) can be resumed to add more rounds (and samples) as follows:

# %%
octo.increment_n_chains(pt, 4) # add four more rounds
chain, pt = octo.octofit_pigeons(pt)

# %%
octo.octoplot(model,chain)

# %% [markdown]
# Much better!

# %% [markdown]
# ## Adding Radial Velocity

# %% [markdown]
# We will now add a few radial velocity points for the star, taken in an interial reference frame (absolute radial velocity).
#
# The paper by Borgniet et al (2019) contains some RV points for this target that were also used by the SCExAO detection. Unfortunately they were not finally uploaded to a public server, but we can guess them from Figure 8 as follows:

# %%
rv_star_like = octo.StarAbsoluteRVLikelihood(
    epoch=[ 54899.5, 55249.5, 57499.5],
    # m/s, positive away from the observer
    rv = [1200, 600, -900] ,
    # m/s
    σ_rv = [1000,1000,1000] ,
    # Instrument name
    instrument_name="my instrument 1",
    # Variable names to use for instument jitter and
    # RV zero-point offset parameters in the model
    jitter="jitter_1",
    offset="offset_1",
)

# %% [markdown]
# We can update our System model to add the new data. We also add variables for the RV offset and jitter for each instrument number (we only have 1 in this example).

# %%
planet_b = octo.Planet(
    name="b",
    basis="Visual{KepOrbit}",
    priors=
    """            
        a ~ LogUniform(0.1, 500)
        e ~ Uniform(0.0, 0.5)
        i ~ Sine()
        ω ~ UniformCircular()
        Ω ~ UniformCircular()
        θ ~ UniformCircular()
        tp = θ_at_epoch_to_tperi(system,b,50000) # use MJD epoch of your data here!!
        mass ~ LogUniform(1, 1000)
    """,
    likelihoods=[astrom_like]
)

hgca_like = octo.HGCALikelihood(gaia_id=756291174721509376)
# The name of your system determines the output file names
sys = octo.System(
    name="HIP100123_with_pma",
    priors=
    """
        M ~ truncated(Normal(1.6, 0.1), lower=0)
        plx ~ gaia_plx(gaia_id=756291174721509376)
        pmra ~ Normal(0,1000)
        pmdec ~ Normal(0,1000)

        offset_1 ~ Normal(0, 5000)
        jitter_1 ~ truncated(Normal(0, 5000),lower=0)
    """,
    likelihoods=[hgca_like, rv_star_like],
    companions=[planet_b]
)
model = octo.LogDensityModel(sys,verbosity=4)

# %%
chain, pt = octo.octofit_pigeons(model, n_rounds=8)

# %%
octo.octoplot(model,chain)

# %% [markdown]
# We can plot the RV orbit against the data in more detail using `rvpostplot` function. This visualizes a single orbit sample, by default the maximum *a-posteriori* sample.

# %%
octo.rvpostplot(model,chain)
