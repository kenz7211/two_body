# %%
"""
Orbital Models of High Velocity Stars in Omega Centauri
Using Octofitterpy
"""
# Out:
# '\nOrbital Models of High Velocity Stars in Omega Centauri\nUsing Octofitterpy\n'

# %%
#Environment variables
# %env JULIA_NUM_THREADS=auto
# %env OCTOFITTERPY_AUTOLOAD_EXTENSIONS=yes
# Out:
# env: JULIA_NUM_THREADS=auto
# env: OCTOFITTERPY_AUTOLOAD_EXTENSIONS=yes

# %%
#Imports 
import numpy as np
import astropy.units as u
from astropy.time import Time
import matplotlib.pylab as plt
import matplotlib.colors as colors
from PyAstronomy import pyasl
import astropy.constants as const
import pandas as pd
import matplotlib.lines as mlines
from astropy.table import Table
from datetime import datetime
from scipy import stats
import matplotlib.cm as cm
import matplotlib.colorbar as colorbar

import sys
sys.path
sys.path.append(r"C:\Users\macke\OneDrive - Saint Marys University\Summer Research 2025\two_body\orbit_utilities")
print(sys.path)
import two_body_utils as utils
import octo_utils 

import octofitterpy as octo
# Out:
# ['C:\\Users\\macke\\anaconda3\\envs\\octo\\python311.zip', 'C:\\Users\\macke\\anaconda3\\envs\\octo\\Lib', 'C:\\Users\\macke\\anaconda3\\envs\\octo\\DLLs', 'C:\\Users\\macke\\anaconda3\\envs\\octo', '', 'C:\\Users\\macke\\anaconda3\\envs\\octo\\Lib\\site-packages', 'C:\\Users\\macke\\anaconda3\\envs\\octo\\Lib\\site-packages\\win32', 'C:\\Users\\macke\\anaconda3\\envs\\octo\\Lib\\site-packages\\win32\\lib', 'C:\\Users\\macke\\anaconda3\\envs\\octo\\Lib\\site-packages\\Pythonwin', 'C:\\Users\\macke\\OneDrive - Saint Marys University\\Summer Research 2025\\two_body\\orbit_utilities']
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython
# Detected Jupyter notebook. Loading juliacall extension. Set `OCTOFITTERPY_AUTOLOAD_EXTENSIONS=no` to disable.
# ['C:\\Users\\macke\\anaconda3\\envs\\octo\\python311.zip', 'C:\\Users\\macke\\anaconda3\\envs\\octo\\Lib', 'C:\\Users\\macke\\anaconda3\\envs\\octo\\DLLs', 'C:\\Users\\macke\\anaconda3\\envs\\octo', '', 'C:\\Users\\macke\\anaconda3\\envs\\octo\\Lib\\site-packages', 'C:\\Users\\macke\\anaconda3\\envs\\octo\\Lib\\site-packages\\win32', 'C:\\Users\\macke\\anaconda3\\envs\\octo\\Lib\\site-packages\\win32\\lib', 'C:\\Users\\macke\\anaconda3\\envs\\octo\\Lib\\site-packages\\Pythonwin', 'C:\\Users\\macke\\OneDrive - Saint Marys University\\Summer Research 2025\\two_body\\orbit_utilities', 'C:\\Users\\macke\\OneDrive - Saint Marys University\\Summer Research 2025\\two_body\\orbit_utilities']
# WARNING: replacing module _ipython.

# %%
# === 1. Select stars and time config ===
star_names = ["A", "B", "C", "D", "E", "F", "G"]
epoch = 2010.0
dt = 1

# Dictionaries to store simulation results and likelihood objects
epochs_mjd = {}
ra_rel = {}
dec_rel = {}
ra_errs = {}
dec_errs = {}

astrom_likelihoods = {}

# === 2. Simulate astrometry and create likelihood objects ===
for name in star_names:
    star = octo_utils.stars[name]
    emjd, ra_r, dec_r, ra_e, dec_e = octo_utils.simulate_astrometry(star=star, epoch=epoch, dt=dt)
    
    epochs_mjd[name] = emjd
    ra_rel[name] = ra_r
    dec_rel[name] = dec_r
    ra_errs[name] = ra_e
    dec_errs[name] = dec_e

    astrom_likelihoods[name] = octo.PlanetRelAstromLikelihood(
        epoch=epochs_mjd[name],             # Observation epochs (Modified Julian Dates)
        ra=ra_rel[name].tolist(),           # Relative Right Ascension values [mas]
        dec=dec_rel[name].tolist(),         # Relative Declination values [mas]
        σ_ra=ra_errs[name],                 # Measurement uncertainties in RA [mas]
        σ_dec=dec_errs[name],               # Measurement uncertainties in Dec [mas]
        cor=[0.0] * len(epochs_mjd[name])   # RA/Dec error correlation (zero for all epochs)
    )

# Access via astrom_likelihoods["A"]

# %%
"""
Companions 
"""
planet_1 = octo.Planet(
    name = "A",                      # Name of the companion (used in output labels)
    basis = "Visual{KepOrbit}",              # Keplerian orbital basis for visual binary
    priors =
    """
        a ~ LogUniform(0.1, 3000)       # Semi-major axis [AU]
        e ~ Uniform(0.0, 0.99)         # Eccentricity
        i ~ Sine()                     # Inclination [rad]
        ω ~ UniformCircular()          # Argument of periastron [rad]
        Ω ~ UniformCircular()          # Longitude of ascending node [rad]
        θ ~ UniformCircular()          # Mean anomaly at reference epoch [rad]
        tp = θ_at_epoch_to_tperi(system, A, 55197.0)  # Reference MJD for θ (adjust to match your data)
    """,
    likelihoods = [astrom_likelihoods["A"]]       # List of likelihood components 
)

planet_2 = octo.Planet(
    name = "B",                      # Name of the companion (used in output labels)
    basis = "Visual{KepOrbit}",              # Keplerian orbital basis for visual binary
    priors =
    """
        a ~ LogUniform(0.1, 3000)       # Semi-major axis [AU]
        e ~ Uniform(0.0, 0.99)         # Eccentricity
        i ~ Sine()                     # Inclination [rad]
        ω ~ UniformCircular()          # Argument of periastron [rad]
        Ω ~ UniformCircular()          # Longitude of ascending node [rad]
        θ ~ UniformCircular()          # Mean anomaly at reference epoch [rad]
        tp = θ_at_epoch_to_tperi(system, B, 55197.0)  # Reference MJD for θ (adjust to match your data)
    """,
    likelihoods = [astrom_likelihoods["B"]]       # List of likelihood components 
)

planet_3 = octo.Planet(
    name = "C",                      # Name of the companion (used in output labels)
    basis = "Visual{KepOrbit}",              # Keplerian orbital basis for visual binary
    priors =
    """
        a ~ LogUniform(0.1, 3000)       # Semi-major axis [AU]
        e ~ Uniform(0.0, 0.99)         # Eccentricity
        i ~ Sine()                     # Inclination [rad]
        ω ~ UniformCircular()          # Argument of periastron [rad]
        Ω ~ UniformCircular()          # Longitude of ascending node [rad]
        θ ~ UniformCircular()          # Mean anomaly at reference epoch [rad]
        tp = θ_at_epoch_to_tperi(system, C, 55197.0)  # Reference MJD for θ (adjust to match your data)
    """,
    likelihoods = [astrom_likelihoods["C"]]       # List of likelihood components 
)

planet_4 = octo.Planet(
    name = "D",                      # Name of the companion (used in output labels)
    basis = "Visual{KepOrbit}",              # Keplerian orbital basis for visual binary
    priors =
    """
        a ~ LogUniform(0.1, 3000)       # Semi-major axis [AU]
        e ~ Uniform(0.0, 0.99)         # Eccentricity
        i ~ Sine()                     # Inclination [rad]
        ω ~ UniformCircular()          # Argument of periastron [rad]
        Ω ~ UniformCircular()          # Longitude of ascending node [rad]
        θ ~ UniformCircular()          # Mean anomaly at reference epoch [rad]
        tp = θ_at_epoch_to_tperi(system, D, 55197.0)  # Reference MJD for θ (adjust to match your data)
    """,
    likelihoods = [astrom_likelihoods["D"]]       # List of likelihood components 
)

planet_5 = octo.Planet(
    name = "E",                      # Name of the companion (used in output labels)
    basis = "Visual{KepOrbit}",              # Keplerian orbital basis for visual binary
    priors =
    """
        a ~ LogUniform(0.1, 3000)       # Semi-major axis [AU]
        e ~ Uniform(0.0, 0.99)         # Eccentricity
        i ~ Sine()                     # Inclination [rad]
        ω ~ UniformCircular()          # Argument of periastron [rad]
        Ω ~ UniformCircular()          # Longitude of ascending node [rad]
        θ ~ UniformCircular()          # Mean anomaly at reference epoch [rad]
        tp = θ_at_epoch_to_tperi(system, E, 55197.0)  # Reference MJD for θ (adjust to match your data)
    """,
    likelihoods = [astrom_likelihoods["E"]]       # List of likelihood components 
)

planet_6 = octo.Planet(
    name = "F",                      # Name of the companion (used in output labels)
    basis = "Visual{KepOrbit}",              # Keplerian orbital basis for visual binary
    priors =
    """
        a ~ LogUniform(0.1, 3000)       # Semi-major axis [AU]
        e ~ Uniform(0.0, 0.99)         # Eccentricity
        i ~ Sine()                     # Inclination [rad]
        ω ~ UniformCircular()          # Argument of periastron [rad]
        Ω ~ UniformCircular()          # Longitude of ascending node [rad]
        θ ~ UniformCircular()          # Mean anomaly at reference epoch [rad]
        tp = θ_at_epoch_to_tperi(system, F, 55197.0)  # Reference MJD for θ (adjust to match your data)
    """,
    likelihoods = [astrom_likelihoods["F"]]       # List of likelihood components 
)

planet_7 = octo.Planet(
    name = "G",                      # Name of the companion (used in output labels)
    basis = "Visual{KepOrbit}",              # Keplerian orbital basis for visual binary
    priors =
    """
        a ~ LogUniform(0.1, 3000)       # Semi-major axis [AU]
        e ~ Uniform(0.0, 0.99)         # Eccentricity
        i ~ Sine()                     # Inclination [rad]
        ω ~ UniformCircular()          # Argument of periastron [rad]
        Ω ~ UniformCircular()          # Longitude of ascending node [rad]
        θ ~ UniformCircular()          # Mean anomaly at reference epoch [rad]
        tp = θ_at_epoch_to_tperi(system, G, 55197.0)  # Reference MJD for θ (adjust to match your data)
    """,
    likelihoods = [astrom_likelihoods["G"]]       # List of likelihood components 
)

# %%
"""
Orbit Fitting and Plotting with Octofitter
"""


# === 3. Define the full system ===
# The system includes the host star’s mass and parallax, and any orbiting companions.

sys = octo.System(
    name = "Omega_Cen",             # System name (used for output files/plot titles)
    priors = 
    """
        M ~ Uniform(200., 100000.)    # Host mass [solar masses]
       plx ~ truncated(Normal(0.18, 0.002), lower=0)     # Parallax [mas]
    """,
    likelihoods = [],                 # No system-level likelihoods in this case
    companions = [planet_1, planet_2, planet_3, planet_4, planet_5, planet_6, planet_7]             # List of orbiting bodies
) 

# === 4. Compile the log-probability model ===
# This prepares the model for sampling. Optional: select a different backend or enable autodiff.
model = octo.LogDensityModel(sys)

# === 5. Fit the model ===
# Run the Hamiltonian Monte Carlo sampler. Default: 1000 warm-up steps, 1000 samples.
# Long runtimes may indicate problems with priors, parameterization, or reference epochs.
chain = octo.octofit(model)
print(chain)  # Print summary of sampled posterior

# Optional: save the summary table to a file
summary_str = repr(chain)

# === 6. Generate diagnostic plots ===
# This will create a set of corner and orbital plots and save them automatically
# as PNG images (default). Use fname="custom_name.pdf" to override.
octo.octoplot(model, chain)
# Out:
# [ Info: Determining initial positions and metric using pathfinder
# ┌ Info: Found a sample of initial positions
# └   initial_logpost_range = (-40919.98514572142, -40919.98514572142)
# ┌ Warning: Falling back to initializing the diagonals with the prior interquartile ranges.
# └ @ Octofitter C:\Users\macke\.julia\packages\Octofitter\3mclS\src\sampling.jl:664
# [ Info: Sampling, beginning with adaptation phase...
# Sampling   0%|█                              |  ETA: 0:54:49
#                                     iterations: 2
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.5
#                                        n_steps: 1
#                                      is_accept: true
#                                acceptance_rate: 0.0
#                                    log_density: -40750.8654188028
#                             hamiltonian_energy: 40785.55612183514
#                       hamiltonian_energy_error: 0.0
#                   max_hamiltonian_energy_error: 2.5856261722115576e6
#                                     tree_depth: 0
#                                numerical_error: true
#                                      step_size: 0.0003512087425726754
#                                  nom_step_size: 0.0003512087425726754
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   0%|█                              |  ETA: 0:41:47
#                                     iterations: 5
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.4
#                                        n_steps: 511
#                                      is_accept: true
#                                acceptance_rate: 0.9465477927739724
#                                    log_density: -39480.608381128004
#                             hamiltonian_energy: 40718.448847559106
#                       hamiltonian_energy_error: 0.03782340854377253
#                   max_hamiltonian_energy_error: 0.11728943881462328
#                                     tree_depth: 9
#                                numerical_error: false
#                                      step_size: 7.910697439559727e-6
#                                  nom_step_size: 7.910697439559727e-6
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   0%|█                              |  ETA: 0:37:05
#                                     iterations: 6
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.33
#                                        n_steps: 255
#                                      is_accept: true
#                                acceptance_rate: 0.9989714268978978
#                                    log_density: -39341.02330055656
#                             hamiltonian_energy: 39502.42185936439
#                       hamiltonian_energy_error: 0.008684463617100846
#                   max_hamiltonian_energy_error: -0.02829534318880178
#                                     tree_depth: 8
#                                numerical_error: false
#                                      step_size: 1.0548230154163072e-5
#                                  nom_step_size: 1.0548230154163072e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   0%|█                              |  ETA: 0:34:45
#                                     iterations: 7
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.29
#                                        n_steps: 255
#                                      is_accept: true
#                                acceptance_rate: 0.9568137521699617
#                                    log_density: -39254.5996832488
#                             hamiltonian_energy: 39366.94989993823
#                       hamiltonian_energy_error: -0.04215640814072685
#                   max_hamiltonian_energy_error: 0.1224131402632338
#                                     tree_depth: 8
#                                numerical_error: false
#                                      step_size: 1.782169300028587e-5
#                                  nom_step_size: 1.782169300028587e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   0%|█                              |  ETA: 0:35:11
#                                     iterations: 8
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.25
#                                        n_steps: 255
#                                      is_accept: true
#                                acceptance_rate: 0.9389578531125968
#                                    log_density: -39069.27680924498
#                             hamiltonian_energy: 39294.4239812062
#                       hamiltonian_energy_error: 0.005701794383639935
#                   max_hamiltonian_energy_error: 0.19843591651442694
#                                     tree_depth: 8
#                                numerical_error: false
#                                      step_size: 2.7802042694132256e-5
#                                  nom_step_size: 2.7802042694132256e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   0%|█                              |  ETA: 0:34:05
#                                     iterations: 9
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.22
#                                        n_steps: 255
#                                      is_accept: true
#                                acceptance_rate: 0.9932493916245386
#                                    log_density: -38654.76035465408
#                             hamiltonian_energy: 39102.13204407516
#                       hamiltonian_energy_error: -0.1014727772490005
#                   max_hamiltonian_energy_error: -0.22226490220054984
#                                     tree_depth: 8
#                                numerical_error: false
#                                      step_size: 4.213329112506041e-5
#                                  nom_step_size: 4.213329112506041e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   0%|█                              |  ETA: 0:33:52
#                                     iterations: 10
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.2
#                                        n_steps: 255
#                                      is_accept: true
#                                acceptance_rate: 0.43211880447234285
#                                    log_density: -38613.84955097282
#                             hamiltonian_energy: 38684.53185070114
#                       hamiltonian_energy_error: 0.6840493173513096
#                   max_hamiltonian_energy_error: 2.4838819979995606
#                                     tree_depth: 8
#                                numerical_error: false
#                                      step_size: 7.690747789178859e-5
#                                  nom_step_size: 7.690747789178859e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   1%|█                              |  ETA: 0:34:45
#                                     iterations: 11
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.18
#                                        n_steps: 511
#                                      is_accept: true
#                                acceptance_rate: 0.944614303823122
#                                    log_density: -38526.385959650666
#                             hamiltonian_energy: 38651.87730789628
#                       hamiltonian_energy_error: 0.04105524059559684
#                   max_hamiltonian_energy_error: 0.1919137256918475
#                                     tree_depth: 9
#                                numerical_error: false
#                                      step_size: 2.3990487006631405e-5
#                                  nom_step_size: 2.3990487006631405e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   1%|█                              |  ETA: 0:34:45
#                                     iterations: 12
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.17
#                                        n_steps: 511
#                                      is_accept: true
#                                acceptance_rate: 0.8596042270729237
#                                    log_density: -38062.872718911196
#                             hamiltonian_energy: 38556.85212268805
#                       hamiltonian_energy_error: 0.1239775895155617
#                   max_hamiltonian_energy_error: 0.605046398282866
#                                     tree_depth: 9
#                                numerical_error: false
#                                      step_size: 3.798081445323276e-5
#                                  nom_step_size: 3.798081445323276e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   1%|█                              |  ETA: 0:37:25
#                                     iterations: 13
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.15
#                                        n_steps: 1023
#                                      is_accept: true
#                                acceptance_rate: 0.997589128637348
#                                    log_density: -36652.14188818255
#                             hamiltonian_energy: 38096.850875424796
#                       hamiltonian_energy_error: -0.288513795218023
#                   max_hamiltonian_energy_error: -0.6971685450407676
#                                     tree_depth: 10
#                                numerical_error: false
#                                      step_size: 4.608032126078735e-5
#                                  nom_step_size: 4.608032126078735e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   1%|█                              |  ETA: 0:36:02
#                                     iterations: 14
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.14
#                                        n_steps: 255
#                                      is_accept: true
#                                acceptance_rate: 0.94543057031291
#                                    log_density: -36501.039008416585
#                             hamiltonian_energy: 36675.8675081534
#                       hamiltonian_energy_error: -0.6640404606223456
#                   max_hamiltonian_energy_error: -0.7724212655157316
#                                     tree_depth: 8
#                                numerical_error: false
#                                      step_size: 8.625003054564736e-5
#                                  nom_step_size: 8.625003054564736e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   1%|█                              |  ETA: 0:55:46
#                                     iterations: 24
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.17
#                                        n_steps: 2047
#                                      is_accept: true
#                                acceptance_rate: 0.9969926382192593
#                                    log_density: -32783.57503887513
#                             hamiltonian_energy: 33765.56145377477
#                       hamiltonian_energy_error: -0.10725454921339406
#                   max_hamiltonian_energy_error: -0.35142018513579387
#                                     tree_depth: 11
#                                numerical_error: false
#                                      step_size: 2.215981526769908e-5
#                                  nom_step_size: 2.215981526769908e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   1%|█                              |  ETA: 0:55:37
#                                     iterations: 25
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.16
#                                        n_steps: 1023
#                                      is_accept: true
#                                acceptance_rate: 0.9919356676647626
#                                    log_density: -32495.24774785786
#                             hamiltonian_energy: 32819.59981573645
#                       hamiltonian_energy_error: 0.014054358623980079
#                   max_hamiltonian_energy_error: -0.674962241340836
#                                     tree_depth: 10
#                                numerical_error: false
#                                      step_size: 3.990284524536207e-5
#                                  nom_step_size: 3.990284524536207e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   1%|█                              |  ETA: 0:54:03
#                                     iterations: 26
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.15
#                                        n_steps: 255
#                                      is_accept: true
#                                acceptance_rate: 0.4323458216353135
#                                    log_density: -32274.312050184904
#                             hamiltonian_energy: 32525.45991071158
#                       hamiltonian_energy_error: -0.8180959656565392
#                   max_hamiltonian_energy_error: 4.451926725141675
#                                     tree_depth: 8
#                                numerical_error: false
#                                      step_size: 7.012669146820413e-5
#                                  nom_step_size: 7.012669146820413e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   1%|█                              |  ETA: 0:55:39
#                                     iterations: 27
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.15
#                                        n_steps: 1023
#                                      is_accept: true
#                                acceptance_rate: 0.9762965129447435
#                                    log_density: -32065.75428991724
#                             hamiltonian_energy: 32311.6900691854
#                       hamiltonian_energy_error: -0.05399045150261372
#                   max_hamiltonian_energy_error: -0.31413338796483004
#                                     tree_depth: 10
#                                numerical_error: false
#                                      step_size: 2.5014360448753786e-5
#                                  nom_step_size: 2.5014360448753786e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   1%|█                              |  ETA: 0:55:21
#                                     iterations: 28
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.14
#                                        n_steps: 511
#                                      is_accept: true
#                                acceptance_rate: 0.9836589886262419
#                                    log_density: -31976.34588279363
#                             hamiltonian_energy: 32089.290094333388
#                       hamiltonian_energy_error: -0.35317674860198167
#                   max_hamiltonian_energy_error: -0.5915520763519453
#                                     tree_depth: 9
#                                numerical_error: false
#                                      step_size: 4.1844822704657825e-5
#                                  nom_step_size: 4.1844822704657825e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   1%|█                              |  ETA: 0:53:50
#                                     iterations: 29
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.14
#                                        n_steps: 255
#                                      is_accept: true
#                                acceptance_rate: 0.7128654558793143
#                                    log_density: -31813.434074165423
#                             hamiltonian_energy: 32003.621141216125
#                       hamiltonian_energy_error: 0.40275809334707446
#                   max_hamiltonian_energy_error: 0.755987692704366
#                                     tree_depth: 8
#                                numerical_error: false
#                                      step_size: 7.083547532857417e-5
#                                  nom_step_size: 7.083547532857417e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   2%|█                              |  ETA: 0:52:46
#                                     iterations: 30
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.13
#                                        n_steps: 511
#                                      is_accept: true
#                                acceptance_rate: 0.9703246948883498
#                                    log_density: -31314.659131521144
#                             hamiltonian_energy: 31838.56332229231
#                       hamiltonian_energy_error: -0.02453432085167151
#                   max_hamiltonian_energy_error: -0.3273807590085198
#                                     tree_depth: 9
#                                numerical_error: false
#                                      step_size: 5.626734077274337e-5
#                                  nom_step_size: 5.626734077274337e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   2%|█                              |  ETA: 0:48:07
#                                     iterations: 35
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.14
#                                        n_steps: 511
#                                      is_accept: true
#                                acceptance_rate: 0.9978741306375168
#                                    log_density: -30699.17601216924
#                             hamiltonian_energy: 30837.774650407344
#                       hamiltonian_energy_error: -0.056031769716355484
#                   max_hamiltonian_energy_error: -0.1028719266068947
#                                     tree_depth: 9
#                                numerical_error: false
#                                      step_size: 3.532824743368258e-5
#                                  nom_step_size: 3.532824743368258e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   2%|█                              |  ETA: 0:47:20
#                                     iterations: 36
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.14
#                                        n_steps: 511
#                                      is_accept: true
#                                acceptance_rate: 0.5711314098173683
#                                    log_density: -30389.785430728047
#                             hamiltonian_energy: 30730.827856919735
#                       hamiltonian_energy_error: 1.1636577090393985
#                   max_hamiltonian_energy_error: 1.4830154736737313
#                                     tree_depth: 9
#                                numerical_error: false
#                                      step_size: 6.03601798668359e-5
#                                  nom_step_size: 6.03601798668359e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   2%|█                              |  ETA: 0:47:11
#                                     iterations: 37
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.14
#                                        n_steps: 1023
#                                      is_accept: true
#                                acceptance_rate: 0.9921283426309743
#                                    log_density: -29947.440147821217
#                             hamiltonian_energy: 30423.489863521572
#                       hamiltonian_energy_error: -0.2788025462614314
#                   max_hamiltonian_energy_error: -0.8009633182118705
#                                     tree_depth: 10
#                                numerical_error: false
#                                      step_size: 3.3591335002994675e-5
#                                  nom_step_size: 3.3591335002994675e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   2%|█                              |  ETA: 0:46:29
#                                     iterations: 38
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.13
#                                        n_steps: 511
#                                      is_accept: true
#                                acceptance_rate: 0.9888314142525908
#                                    log_density: -29607.05708802559
#                             hamiltonian_energy: 29976.167894739297
#                       hamiltonian_energy_error: -0.26432534076593583
#                   max_hamiltonian_energy_error: -0.8548442254541442
#                                     tree_depth: 9
#                                numerical_error: false
#                                      step_size: 5.609233356321682e-5
#                                  nom_step_size: 5.609233356321682e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   2%|█                              |  ETA: 0:42:22
#                                     iterations: 48
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.12
#                                        n_steps: 511
#                                      is_accept: true
#                                acceptance_rate: 0.9967112513739081
#                                    log_density: -28053.953947917053
#                             hamiltonian_energy: 28321.367456090768
#                       hamiltonian_energy_error: -0.06152027609641664
#                   max_hamiltonian_energy_error: -0.33436347762471996
#                                     tree_depth: 9
#                                numerical_error: false
#                                      step_size: 4.5310941831232265e-5
#                                  nom_step_size: 4.5310941831232265e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   2%|█                              |  ETA: 0:41:57
#                                     iterations: 49
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.12
#                                        n_steps: 511
#                                      is_accept: true
#                                acceptance_rate: 0.7934971097648166
#                                    log_density: -28010.58252778761
#                             hamiltonian_energy: 28084.986560956942
#                       hamiltonian_energy_error: -0.02289989363634959
#                   max_hamiltonian_energy_error: 1.1118850159764406
#                                     tree_depth: 9
#                                numerical_error: false
#                                      step_size: 7.333376902819143e-5
#                                  nom_step_size: 7.333376902819143e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   2%|█                              |  ETA: 0:41:28
#                                     iterations: 50
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.12
#                                        n_steps: 511
#                                      is_accept: true
#                                acceptance_rate: 0.6542153806720447
#                                    log_density: -27878.110985051928
#                             hamiltonian_energy: 28043.42999329184
#                       hamiltonian_energy_error: 0.11486612897715531
#                   max_hamiltonian_energy_error: 1.7624584394943668
#                                     tree_depth: 9
#                                numerical_error: false
#                                      step_size: 7.280052857027482e-5
#                                  nom_step_size: 7.280052857027482e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   3%|█                              |  ETA: 0:41:02
#                                     iterations: 51
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.12
#                                        n_steps: 511
#                                      is_accept: true
#                                acceptance_rate: 0.9777896022627794
#                                    log_density: -27756.309717511314
#                             hamiltonian_energy: 27910.417457579686
#                       hamiltonian_energy_error: 0.27041548847410013
#                   max_hamiltonian_energy_error: -0.5528830751754867
#                                     tree_depth: 9
#                                numerical_error: false
#                                      step_size: 5.204936238589367e-5
#                                  nom_step_size: 5.204936238589367e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   3%|█                              |  ETA: 0:40:36
#                                     iterations: 52
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.12
#                                        n_steps: 511
#                                      is_accept: true
#                                acceptance_rate: 0.9193241140282158
#                                    log_density: -27422.7454522516
#                             hamiltonian_energy: 27796.558112521594
#                       hamiltonian_energy_error: -0.6267540471999382
#                   max_hamiltonian_energy_error: -1.3593941655999515
#                                     tree_depth: 9
#                                numerical_error: false
#                                      step_size: 7.973338496579626e-5
#                                  nom_step_size: 7.973338496579626e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   3%|█                              |  ETA: 0:40:45
#                                     iterations: 54
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.13
#                                        n_steps: 2047
#                                      is_accept: true
#                                acceptance_rate: 0.9859673325469865
#                                    log_density: -27242.350159715723
#                             hamiltonian_energy: 27457.35085123149
#                       hamiltonian_energy_error: 0.04961526232000324
#                   max_hamiltonian_energy_error: -0.4332798124924011
#                                     tree_depth: 11
#                                numerical_error: false
#                                      step_size: 2.5492528555504038e-5
#                                  nom_step_size: 2.5492528555504038e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   3%|█                              |  ETA: 0:41:05
#                                     iterations: 55
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.13
#                                        n_steps: 1023
#                                      is_accept: true
#                                acceptance_rate: 0.9731284514938897
#                                    log_density: -26676.375943424544
#                             hamiltonian_energy: 27266.984638680504
#                       hamiltonian_energy_error: -0.42855876075918786
#                   max_hamiltonian_energy_error: -0.6879660229060391
#                                     tree_depth: 10
#                                numerical_error: false
#                                      step_size: 3.964080568032273e-5
#                                  nom_step_size: 3.964080568032273e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   3%|█                              |  ETA: 0:40:45
#                                     iterations: 56
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.12
#                                        n_steps: 511
#                                      is_accept: true
#                                acceptance_rate: 0.8755586920940597
#                                    log_density: -26343.05602818382
#                             hamiltonian_energy: 26699.24807228572
#                       hamiltonian_energy_error: -0.2543977390960208
#                   max_hamiltonian_energy_error: 0.9709749048815866
#                                     tree_depth: 9
#                                numerical_error: false
#                                      step_size: 5.9524755094013115e-5
#                                  nom_step_size: 5.9524755094013115e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   3%|█                              |  ETA: 0:40:30
#                                     iterations: 57
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.12
#                                        n_steps: 511
#                                      is_accept: true
#                                acceptance_rate: 0.5535034707473936
#                                    log_density: -26010.980319096463
#                             hamiltonian_energy: 26375.10089740138
#                       hamiltonian_energy_error: 0.2966194293621811
#                   max_hamiltonian_energy_error: 2.01901383150107
#                                     tree_depth: 9
#                                numerical_error: false
#                                      step_size: 7.127456377120233e-5
#                                  nom_step_size: 7.127456377120233e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   3%|█                              |  ETA: 0:40:15
#                                     iterations: 58
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.12
#                                        n_steps: 511
#                                      is_accept: true
#                                acceptance_rate: 0.6599150415988388
#                                    log_density: -25815.050028455265
#                             hamiltonian_energy: 26046.164077546742
#                       hamiltonian_energy_error: -0.02268857754461351
#                   max_hamiltonian_energy_error: 1.1991755304479739
#                                     tree_depth: 9
#                                numerical_error: false
#                                      step_size: 4.120707741880075e-5
#                                  nom_step_size: 4.120707741880075e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   3%|█                              |  ETA: 0:40:54
#                                     iterations: 59
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.12
#                                        n_steps: 1023
#                                      is_accept: true
#                                acceptance_rate: 0.8789253412644511
#                                    log_density: -25434.902956174345
#                             hamiltonian_energy: 25852.673290516224
#                       hamiltonian_energy_error: 0.2574756906979019
#                   max_hamiltonian_energy_error: 0.28314398719521705
#                                     tree_depth: 10
#                                numerical_error: false
#                                      step_size: 3.0437723022502926e-5
#                                  nom_step_size: 3.0437723022502926e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   3%|█                              |  ETA: 0:41:14
#                                     iterations: 60
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.12
#                                        n_steps: 1023
#                                      is_accept: true
#                                acceptance_rate: 0.9875409083427341
#                                    log_density: -25103.696990162192
#                             hamiltonian_energy: 25471.202274976837
#                       hamiltonian_energy_error: -0.0859360330614436
#                   max_hamiltonian_energy_error: -0.2729795274390199
#                                     tree_depth: 10
#                                numerical_error: false
#                                      step_size: 3.674364673991494e-5
#                                  nom_step_size: 3.674364673991494e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   3%|█                              |  ETA: 0:41:05
#                                     iterations: 61
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.11
#                                        n_steps: 511
#                                      is_accept: true
#                                acceptance_rate: 0.9712233945588299
#                                    log_density: -24564.553037973743
#                             hamiltonian_energy: 25131.78292030231
#                       hamiltonian_energy_error: -0.42531611024969607
#                   max_hamiltonian_energy_error: -0.6975164016403141
#                                     tree_depth: 9
#                                numerical_error: false
#                                      step_size: 5.6278868260330237e-5
#                                  nom_step_size: 5.6278868260330237e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   4%|██                             |  ETA: 0:51:20
#                                     iterations: 71
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.14
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9542313081347469
#                                    log_density: -21394.44920757386
#                             hamiltonian_energy: 21442.88010523853
#                       hamiltonian_energy_error: -0.0034302843050681986
#                   max_hamiltonian_energy_error: 0.32027527779791853
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 1.9176817163646547e-5
#                                  nom_step_size: 1.9176817163646547e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   4%|██                             |  ETA: 0:52:59
#                                     iterations: 72
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.14
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9489606496260584
#                                    log_density: -21351.04153529367
#                             hamiltonian_energy: 21426.2567016605
#                       hamiltonian_energy_error: 0.003036488447833108
#                   max_hamiltonian_energy_error: 0.37326979604404187
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 2.6792159358199193e-5
#                                  nom_step_size: 2.6792159358199193e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   4%|██                             |  ETA: 0:54:21
#                                     iterations: 73
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.14
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.696251140975485
#                                    log_density: -21325.84259625621
#                             hamiltonian_energy: 21380.496376706054
#                       hamiltonian_energy_error: -0.018996239155967487
#                   max_hamiltonian_energy_error: 1.4717474967728776
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 3.689311166359979e-5
#                                  nom_step_size: 3.689311166359979e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   4%|██                             |  ETA: 0:55:31
#                                     iterations: 74
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.14
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.8597778389707885
#                                    log_density: -21263.17331978303
#                             hamiltonian_energy: 21360.88270127225
#                       hamiltonian_energy_error: 0.0826828533790831
#                   max_hamiltonian_energy_error: 0.7243994595046388
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 3.0092458206701706e-5
#                                  nom_step_size: 3.0092458206701706e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   4%|██                             |  ETA: 0:56:41
#                                     iterations: 75
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.13
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9822221277161628
#                                    log_density: -21203.628611324148
#                             hamiltonian_energy: 21295.93356131491
#                       hamiltonian_energy_error: -0.25271422956575407
#                   max_hamiltonian_energy_error: -0.6855977088453074
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 3.4381280215195375e-5
#                                  nom_step_size: 3.4381280215195375e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   4%|██                             |  ETA: 0:57:36
#                                     iterations: 76
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.14
#                                        n_steps: 3636
#                                      is_accept: true
#                                acceptance_rate: 0.8899092477399048
#                                    log_density: -21162.47518762042
#                             hamiltonian_energy: 21237.1352184235
#                       hamiltonian_energy_error: -0.1921604976269009
#                   max_hamiltonian_energy_error: 2155.071412912137
#                                     tree_depth: 11
#                                numerical_error: true
#                                      step_size: 5.034221545842527e-5
#                                  nom_step_size: 5.034221545842527e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   4%|██                             |  ETA: 0:57:51
#                                     iterations: 77
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.14
#                                        n_steps: 2047
#                                      is_accept: true
#                                acceptance_rate: 0.320967534664598
#                                    log_density: -21114.2502511461
#                             hamiltonian_energy: 21200.266232084454
#                       hamiltonian_energy_error: -1.5432661466766149
#                   max_hamiltonian_energy_error: 5.722253543528495
#                                     tree_depth: 11
#                                numerical_error: false
#                                      step_size: 6.089284585725302e-5
#                                  nom_step_size: 6.089284585725302e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   4%|██                             |  ETA: 0:59:39
#                                     iterations: 78
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.14
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.909813381728516
#                                    log_density: -21081.95823554321
#                             hamiltonian_energy: 21152.88962269464
#                       hamiltonian_energy_error: 0.11506802613803302
#                   max_hamiltonian_energy_error: 0.35491409699898213
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 2.3330361005149597e-5
#                                  nom_step_size: 2.3330361005149597e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   4%|██                             |  ETA: 1:01:27
#                                     iterations: 79
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.14
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9706818401826997
#                                    log_density: -21026.092884116013
#                             hamiltonian_energy: 21126.10588313156
#                       hamiltonian_energy_error: -0.09620583701325813
#                   max_hamiltonian_energy_error: -0.4113326269107347
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 2.942462446261055e-5
#                                  nom_step_size: 2.942462446261055e-5
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[11.469512621977815, 0.0005 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling   4%|██                             |  ETA: 1:03:00
#                                     iterations: 80
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.15
#                                        n_steps: 3877
# ...
#                                      is_accept: true
#                                acceptance_rate: 0.990061336722805
#                                    log_density: -18867.412562480324
#                             hamiltonian_energy: 18889.992673686706
#                       hamiltonian_energy_error: -0.011025730811525136
#                   max_hamiltonian_energy_error: -0.07524485924295732
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 0.0002848948004071397
#                                  nom_step_size: 0.0002848948004071397
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.011594693896169411, 9.91 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  77%|█████████████████████████      |  ETA: 0:37:59
#                                     iterations: 1549
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.15
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9819265071543127
#                                    log_density: -18861.19869432604
#                             hamiltonian_energy: 18908.875964758372
#                       hamiltonian_energy_error: 0.05555339713464491
#                   max_hamiltonian_energy_error: 0.07137472092290409
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 0.0002848948004071397
#                                  nom_step_size: 0.0002848948004071397
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.011594693896169411, 9.91 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  78%|█████████████████████████      |  ETA: 0:37:53
#                                     iterations: 1550
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.15
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.8711045616798784
#                                    log_density: -18863.46825302341
#                             hamiltonian_energy: 18894.59317389834
#                       hamiltonian_energy_error: -0.07438402087063878
#                   max_hamiltonian_energy_error: 0.3704327876366733
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 0.0002848948004071397
#                                  nom_step_size: 0.0002848948004071397
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.011594693896169411, 9.91 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  78%|█████████████████████████      |  ETA: 0:37:48
#                                     iterations: 1551
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.15
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9421911022424821
#                                    log_density: -18864.818963067264
#                             hamiltonian_energy: 18903.075221617317
#                       hamiltonian_energy_error: 0.12250108109219582
#                   max_hamiltonian_energy_error: 0.16366419538098853
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 0.0002848948004071397
#                                  nom_step_size: 0.0002848948004071397
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.011594693896169411, 9.91 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  78%|█████████████████████████      |  ETA: 0:37:43
#                                     iterations: 1552
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.15
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.999814624020539
#                                    log_density: -18860.88142992442
#                             hamiltonian_energy: 18893.71808193431
#                       hamiltonian_energy_error: -0.14266705046975403
#                   max_hamiltonian_energy_error: -0.15995898943583597
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 0.0002848948004071397
#                                  nom_step_size: 0.0002848948004071397
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.011594693896169411, 9.91 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  78%|█████████████████████████      |  ETA: 0:37:38
#                                     iterations: 1553
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.15
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9982547831845956
#                                    log_density: -18863.24993591946
#                             hamiltonian_energy: 18892.408560889427
#                       hamiltonian_energy_error: 0.001311247131525306
#                   max_hamiltonian_energy_error: 0.008221779204177437
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 0.0002848948004071397
#                                  nom_step_size: 0.0002848948004071397
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.011594693896169411, 9.91 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  78%|█████████████████████████      |  ETA: 0:37:33
#                                     iterations: 1554
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.15
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.848140178241225
#                                    log_density: -18864.609804889267
#                             hamiltonian_energy: 18887.082312202263
#                       hamiltonian_energy_error: 0.33403879223624244
#                   max_hamiltonian_energy_error: 0.35262790443448466
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 0.0002848948004071397
#                                  nom_step_size: 0.0002848948004071397
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.011594693896169411, 9.91 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  78%|█████████████████████████      |  ETA: 0:37:29
#                                     iterations: 1555
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.15
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.8790652128025545
#                                    log_density: -18863.712369932156
#                             hamiltonian_energy: 18893.490483175025
#                       hamiltonian_energy_error: -0.15454529752605595
#                   max_hamiltonian_energy_error: 0.42937487152812537
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 0.0002848948004071397
#                                  nom_step_size: 0.0002848948004071397
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.011594693896169411, 9.91 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  78%|█████████████████████████      |  ETA: 0:37:24
#                                     iterations: 1556
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.15
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.995549051383737
#                                    log_density: -18869.530957851297
#                             hamiltonian_energy: 18899.005242523872
#                       hamiltonian_energy_error: -0.0452194328790938
#                   max_hamiltonian_energy_error: -0.1642879576247651
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 0.0002848948004071397
#                                  nom_step_size: 0.0002848948004071397
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.011594693896169411, 9.91 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  78%|█████████████████████████      |  ETA: 0:37:19
#                                     iterations: 1557
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.15
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.954151805943733
#                                    log_density: -18868.464337129044
#                             hamiltonian_energy: 18903.477735639426
#                       hamiltonian_energy_error: -0.05623071299487492
#                   max_hamiltonian_energy_error: 0.15568089941371
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 0.0002848948004071397
#                                  nom_step_size: 0.0002848948004071397
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.011594693896169411, 9.91 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  78%|█████████████████████████      |  ETA: 0:37:14
#                                     iterations: 1558
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.15
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9977799425096179
#                                    log_density: -18869.400972135107
#                             hamiltonian_energy: 18896.687266960413
#                       hamiltonian_energy_error: -0.020739142819365952
#                   max_hamiltonian_energy_error: -0.061983511590369744
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 0.0002848948004071397
#                                  nom_step_size: 0.0002848948004071397
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.011594693896169411, 9.91 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  78%|█████████████████████████      |  ETA: 0:37:09
#                                     iterations: 1559
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.15
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9969910561286933
#                                    log_density: -18867.13713940094
#                             hamiltonian_energy: 18892.678570348304
#                       hamiltonian_energy_error: -0.023763101944496157
#                   max_hamiltonian_energy_error: -0.03686163735255832
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 0.0002848948004071397
#                                  nom_step_size: 0.0002848948004071397
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.011594693896169411, 9.91 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  78%|█████████████████████████      |  ETA: 0:37:05
#                                     iterations: 1560
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.15
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.6073332545555288
#                                    log_density: -18863.153787851857
#                             hamiltonian_energy: 18899.219838360837
#                       hamiltonian_energy_error: 0.4848867843793414
#                   max_hamiltonian_energy_error: 1.1915754541951173
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 0.0002848948004071397
#                                  nom_step_size: 0.0002848948004071397
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.011594693896169411, 9.91 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  78%|█████████████████████████      |  ETA: 0:37:01
#                                     iterations: 1561
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.15
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9999936523090784
#                                    log_density: -18864.08456468766
#                             hamiltonian_energy: 18885.661551227764
#                       hamiltonian_energy_error: -0.11040560929905041
#                   max_hamiltonian_energy_error: -0.5086108528921613
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 0.0002848948004071397
#                                  nom_step_size: 0.0002848948004071397
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.011594693896169411, 9.91 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  78%|█████████████████████████      |  ETA: 0:36:56
#                                     iterations: 1562
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.15
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.949340780925279
#                                    log_density: -18861.83116832761
#                             hamiltonian_energy: 18889.467627596743
#                       hamiltonian_energy_error: -0.25821523493505083
#                   max_hamiltonian_energy_error: -0.36497608187710284
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 0.0002848948004071397
#                                  nom_step_size: 0.0002848948004071397
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.011594693896169411, 9.91 ...])

# %%
octo.octoplot(model, chain, companion=planet_1)

# %%
# Orbit Plot
orbit_plot = octo.octoplot(model,chain, show_physical_orbit = True)

# === companion names ===
companion_names = "ABCDEFG"

# === Build filename ===
plot_name = f"octo_orbit_{companion_names}"
timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
filename = rf"C:\Users\macke\OneDrive - Saint Marys University\Summer Research 2025\Plots\{plot_name}_{timestamp}.png"

# Save the image bytes to a file
with open(filename, "wb") as f:
    f.write(orbit_plot.data)

display(orbit_plot)

# %%
# Generate the corner plot
corner_plot = octo.octocorner(model, chain, small=True)

# === companion names ===
companion_names = "ABCDEFG"

# === Build filename ===
plot_name = f"octo_corner_{companion_names}"
timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
filename = rf"C:\Users\macke\OneDrive - Saint Marys University\Summer Research 2025\Plots\{plot_name}_{timestamp}.png"

# Save the image bytes to a file
with open(filename, "wb") as f:
    f.write(corner_plot.data)

display(corner_plot)

# %%
# === Define companions and labels ===
companions = [planet_1, planet_2, planet_3, planet_4, planet_5, planet_6, planet_7]
labels = ["A", "B", "C", "D", "E", "F", "G"]

# === Output folder ===
output_dir = r"C:\Users\macke\OneDrive - Saint Marys University\Summer Research 2025\Plots"

# === Loop through each companion ===
for comp, label in zip(companions, labels):
    timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

    # === Orbit Plot ===
    orbit_plot = octo.octoplot(model, chain, companion=comp, show_physical_orbit=True)
    orbit_fname = rf"{output_dir}\octo_orbit_{label}_{timestamp}.pdf"
    with open(orbit_fname, "wb") as f:
        f.write(orbit_plot.data)
    display(orbit_plot)

    # === Corner Plot ===
    corner_plot = octo.octocorner(model, chain, companion=comp, small=True)
    corner_fname = rf"{output_dir}\octo_corner_{label}_{timestamp}.pdf"
    with open(corner_fname, "wb") as f:
        f.write(corner_plot.data)
    display(corner_plot)

# %%
# """
# Saving your chain:
# Variables can be retrieved from the chains using the following syntax:
#     sma_planet_b = chain["b_a",:,:] 
# The first index is the name of the variable in the model (as a string or symbol).
# Planet-specific parameters are prefixed with the planet's name and an underscore (e.g., 'A_a' for semi-major axis of planet A).
# """

# # --- Extract and print best-fit orbital parameters for planet A (16th, 50th, 84th percentiles) ---

# # Semi-major axis in astronomical units
# print("Semi-major axis [AU]:", np.percentile(chain["A_a"], [16, 50, 84]))

# # Eccentricity (unitless, range: 0–1)
# print("Eccentricity:", np.percentile(chain["A_e"], [16, 50, 84]))

# # Orbital inclination in degrees (0° = face-on, 90° = edge-on)
# print("Inclination [deg]:", np.percentile(chain["A_i"], [16, 50, 84]))

# # Argument of periastron (angle from ascending node to periastron, in degrees)
# print("Argument of periastron [deg]:", np.percentile(chain["A_ω"], [16, 50, 84]))

# # Longitude of the ascending node (angle of orbit's orientation in space)
# print("Longitude of ascending node [deg]:", np.percentile(chain["A_Ω"], [16, 50, 84]))

# # Time of periastron passage in Modified Julian Date (MJD)
# print("Time of periastron passage [MJD]:", np.percentile(chain["A_tp"], [16, 50, 84]))

# # Convert MJD to calendar years (ISO format) using Octofitter's Julian date conversion
# tp_mjds = np.percentile(chain["A_tp"], [16, 50, 84])
# tp_years_octo = [octo.mjd2date(float(mjd)) for mjd in tp_mjds]
# print("Time of periastron passage [years]:", tp_years_octo)

# # Total system mass (usually primary + companion) in solar masses
# print("Total Mass [Solar Masses]:", np.percentile(chain["M"], [16, 50, 84]))

# %%
# """
# Functions
# """

# def fake_pos(pos, pm, acc, dt):
#     """
#     Gives a fake observed position using an observed angular position, velocity, and acceleration

#     Parameters:
#     - pos : Initial position (in mas)
#     - pm : Proper motion (in mas/yr)
#     - acc : Acceleration (in mas/yr²)
#     - dt : Time offset(s) from the reference epoch in years

#     Returns:
#     - pos_final : calculated position (in mas)
#     """
#     return pos + pm * dt + 0.5 * acc * dt**2

# def propagate_error(sigma_pm, sigma_acc, dt):
#     """
#     Propagates uncertainty in position due to uncertainties in
#     proper motion and acceleration over time. No uncertainty in initial position is available.

#     Parameters:
#     - sigma_pm Uncertainty in proper motion (mas/yr)
#     - sigma_acc : Uncertainty in acceleration (mas/yr²)
#     - dt : Time from reference epoch (in years)

#     Returns:
#     - sigma_pos : Uncertainty in predicted position at time dt (in mas)
#     """
#     term_mu = (dt * sigma_pm) ** 2
#     term_acc = (0.5 * dt**2 * sigma_acc) ** 2
#     return np.sqrt(term_mu + term_acc)

# %%
# """
# Mock dataset from single epoch observations for star A
# """

# # Time offset between epochs in years
# dt = 10              
# # Decimal-year epochs
# epochs_years = np.array([2010 - dt, 2010, 2010 + dt])   
# # Convert to MJD
# epochs_mjd = [octo.years2mjd(float(y)) for y in epochs_years]

# # Observational Data 
# # Star A
# ra_A = (201.6967263*u.deg).to(u.mas).value
# dec_A = (-47.4795835*u.deg).to(u.mas).value
# pm_ra_A = 3.563 # mas year^-1
# pm_dec_A = 2.564 # mas year^-1
# acc_ra_A = -0.0069 # mas year^-2
# acc_dec_A = 0.0085 # mas year^-2
# # Omega Centauri Center 
# # We find the center to be at (α,δ) = (13:26:47.24, −47:28:46.45).
# # from https://iopscience.iop.org/article/10.1088/0004-637X/710/2/1032
# # reference 6 in Haberle et al. (2024; Nature, Vol. 631) 
# # We assume the IMBH is located at the cluster center
# ra_cm_deg = 201.696834*u.deg
# dec_cm_deg = -47.479569*u.deg
# # Omega Centauri centre in mas
# ra_cm_mas  = ra_cm_deg.to(u.mas).value
# dec_cm_mas = dec_cm_deg.to(u.mas).value

# # Uncertainties 
# sigma_pm_ra_A = 0.038 # mas year^-1
# sigma_pm_dec_A = 0.055 # mas year^-1
# sigma_acc_ra_A = 0.0083 # mas year^-2
# sigma_acc_dec_A = 0.0098 # mas year^-2


# # Mock future and past observations
# future_ra_A  = fake_pos(ra_A,  pm_ra_A,  acc_ra_A,  dt)
# future_dec_A = fake_pos(dec_A, pm_dec_A, acc_dec_A, dt)
# past_ra_A    = fake_pos(ra_A,  pm_ra_A,  acc_ra_A, -dt)
# past_dec_A   = fake_pos(dec_A, pm_dec_A, acc_dec_A, -dt)

# future_ra_A_err  = propagate_error(sigma_pm_ra_A,  sigma_acc_ra_A,  dt)
# future_dec_A_err = propagate_error(sigma_pm_dec_A, sigma_acc_dec_A, dt)
# past_ra_A_err    = propagate_error(sigma_pm_ra_A,  sigma_acc_ra_A, -dt)
# past_dec_A_err   = propagate_error(sigma_pm_dec_A, sigma_acc_dec_A, -dt)

# # Arrays of absolute positions 
# ra_vals_A  = np.array([past_ra_A,  ra_A,  future_ra_A])   # mas
# dec_vals_A = np.array([past_dec_A, dec_A, future_dec_A])  # mas

# # Convert to positions relative to the assumed center of mass
# ra_rel_A  = ra_vals_A  - ra_cm_mas      # delta RA = companion − host  [mas]
# dec_rel_A = dec_vals_A - dec_cm_mas     # delta Dec = companion − host [mas]

# # Uncertainty is required for Octofitter for all positions (small uncertainty instead of zero)
# ra_errs_A = [past_ra_A_err, 1e-6, future_ra_A_err]
# dec_errs_A = [past_dec_A_err, 1e-6, future_dec_A_err]

# # Testing 
# print()
# print("Mock future RA of star A:", (future_ra_A*u.mas).to(u.deg), "±",(future_ra_A_err*u.mas).to(u.deg))
# print("Mock future DEC of star A:", (future_dec_A*u.mas).to(u.deg), "±",(future_dec_A_err*u.mas).to(u.deg))
# print()
# print("Mock past RA of star A:", (past_ra_A*u.mas).to(u.deg), "±",(past_ra_A_err*u.mas).to(u.deg))
# print("Mock past DEC of star A:", (past_dec_A*u.mas).to(u.deg), "±",(past_dec_A_err*u.mas).to(u.deg))
# print()

# %%
# """
# Testing Values
# """
# # Manual values
# ra_vals_manual  = np.array([past_ra_A,  ra_A,  future_ra_A])
# dec_vals_manual = np.array([past_dec_A, dec_A, future_dec_A])
# ra_rel_manual   = ra_vals_manual - ra_cm_mas
# dec_rel_manual  = dec_vals_manual - dec_cm_mas
# ra_errs_manual  = [past_ra_A_err, 1e-6, future_ra_A_err]
# dec_errs_manual = [past_dec_A_err, 1e-6, future_dec_A_err]

# # octo_orbit values
# star = octo_utils.stars["A"]
# epoch = 2010.0
# dt = 10
# epochs_func, ra_rel_func, dec_rel_func, ra_errs_func, dec_errs_func = octo_utils.simulate_astrometry(star, epoch, dt)

# print("RA rel diff:", ra_rel_func - ra_rel_manual)
# print("Dec rel diff:", dec_rel_func - dec_rel_manual)
# print("RA err diff:", np.array(ra_errs_func) - np.array(ra_errs_manual))
# print("Dec err diff:", np.array(dec_errs_func) - np.array(dec_errs_manual))

# %%
# """
# Orbital Calculations and Plots with Octofitter
# """
# # We start by defining a likelihood object for the relative astrometry of the star.
# astrom_like = octo.PlanetRelAstromLikelihood(
#     # MJD
#     epoch = epochs_mjd,      # Observation MJDs
#     # delta RA, milliarcseconds (East is positive)
#     ra = ra_rel_A.tolist(),      # Relative RA (mas)
#     # delta DEC, milliarcseconds (North is positive)
#     dec = dec_rel_A.tolist(),         # Relative Dec (mas)
#     # Uncertainty on RA, milliarcseconds
#     σ_ra = ra_errs_A,        # RA uncertainties (mas)
#     # Uncertainty on DEC, milliarcseconds
# 	σ_dec = dec_errs_A,      # Dec uncertainties (mas)
#     # Corelation between RA and DEC uncertainties
# 	cor= [0.0] * 3                    # No RA/Dec correlation
# )

# # We now define the orbiting star component of our model. 
# # We specify a name, an orbital basis, our priors, and list any likelihood objects.
# # Note! Change the reference epoch provided to θ_at_epoch_to_tperi from 50000 to one where your astrometry is defined
# star_A = octo.Planet(
#     name="A",
#     basis="Visual{KepOrbit}",
#     priors=
#     """            
#         a ~ LogUniform(0.1, 500)
#         e ~ Uniform(0.0, 0.99)
#         i ~ Sine()
#         ω ~ UniformCircular()
#         Ω ~ UniformCircular()
#         θ ~ UniformCircular()
#         tp = θ_at_epoch_to_tperi(system,A,55197.0) # use MJD epoch of your data here!!
#     """,
#     likelihoods=[astrom_like]
# )


# # Now we define our system, containing our star. 
# # We provide it with a name (used to specify the output file names and plot legends), 
# # our priors, a list of likelihood objects for the system as a whole (e.g., proper motion anomaly, radial velocity), 
# # and a list of companion models.
# # The name of your system determines the output file names
# sys = octo.System(
#     name="Omega_Cen_A",
#     priors = 
#     """
#         M ~ truncated(Normal(1.2, 0.1), lower=0)
#         plx ~ truncated(Normal(50.0, 0.02), lower=0)
#     """,
#     likelihoods=[],
#     companions=[star_A]
# )
# # We then compile our model. 
# # There are a few options for this function (for example, you can select the autodiff backend), but the defaults are reasonable.
# model = octo.LogDensityModel(sys)

# # We now fit the model. By default, this uses a Hamiltonian Monte Carlo sampler with 1000 steps of adaptation (discarded) and 1000 iterations. 
# # You can pass eg, adaptation=5000, iterations=25000, if you would like more points for your plots.
# # Long runtimes indiciate an error in your model
# # The orbit fitting should take <30 s for this example. 
# # If you find it takes much longer on your code, double check the model and priors. Is the epoch you specified for tperi the same as your data?
# # Numerical errors indicate a problem with sampling 
# # If you see a report that numerical errors were encountered during sampling, the results may not be statistically valid. 
# # You could re-try sampling, or investigate your model for errors.
# chain = octo.octofit(model)
# print(chain)

# # If you wish to save this summary table to a text file, you can convert it to a string like so:
# summary_str = repr(chain)

# # Use the octoplot function to generate plots. 
# # You can use keyword arguments (see documentation) to control which output panels appear. 
# # By default, they will be chosen automatically based on the kinds of data likelihoods you supply to the model.
# # The output is automatically saved to a PNG file in your current folder, with a name based on the name of the System you created. 
# # You can also customize this using the fname argument (see docs for more details). 
# # You can change the image format (eg to PDF) by changing the file name extension.
# octo.octoplot(model,chain)
