# %%
#Environment variables
# %env JULIA_NUM_THREADS=auto
# %env OCTOFITTERPY_AUTOLOAD_EXTENSIONS=yes
# Out:
# env: JULIA_NUM_THREADS=auto
# env: OCTOFITTERPY_AUTOLOAD_EXTENSIONS=yes

# %%
#Imports 
import numpy as np
import astropy.units as u
from astropy.time import Time
import matplotlib.pylab as plt
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from PyAstronomy import pyasl
import astropy.constants as const
import pandas as pd
import matplotlib.lines as mlines
from astropy.table import Table
from datetime import datetime
from scipy import stats
import matplotlib.cm as cm
import matplotlib.colorbar as colorbar

import sys
sys.path
sys.path.append(r"C:\Users\macke\OneDrive - Saint Marys University\Summer Research 2025\two_body\orbit_utilities")
print(sys.path)
import two_body_utils as utils

import octofitterpy as octo
# Out:
# ['C:\\Users\\macke\\anaconda3\\envs\\octo\\python311.zip', 'C:\\Users\\macke\\anaconda3\\envs\\octo\\Lib', 'C:\\Users\\macke\\anaconda3\\envs\\octo\\DLLs', 'C:\\Users\\macke\\anaconda3\\envs\\octo', '', 'C:\\Users\\macke\\anaconda3\\envs\\octo\\Lib\\site-packages', 'C:\\Users\\macke\\anaconda3\\envs\\octo\\Lib\\site-packages\\win32', 'C:\\Users\\macke\\anaconda3\\envs\\octo\\Lib\\site-packages\\win32\\lib', 'C:\\Users\\macke\\anaconda3\\envs\\octo\\Lib\\site-packages\\Pythonwin', 'C:\\Users\\macke\\OneDrive - Saint Marys University\\Summer Research 2025\\two_body\\orbit_utilities']
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython
# Detected Jupyter notebook. Loading juliacall extension. Set `OCTOFITTERPY_AUTOLOAD_EXTENSIONS=no` to disable.
# WARNING: replacing module _ipython.

# %%
"""
Functions
"""

def fake_pos(pos, pm, acc, dt):
    """
    Gives a fake observed position using an observed angular position, velocity, and acceleration

    Parameters:
    - pos : Initial position (in mas)
    - pm : Proper motion (in mas/yr)
    - acc : Acceleration (in mas/yr²)
    - dt : Time offset(s) from the reference epoch in years

    Returns:
    - pos_final : calculated position (in mas)
    """
    return pos + pm * dt + 0.5 * acc * dt**2

def propagate_error(sigma_pm, sigma_acc, dt):
    """
    Propagates uncertainty in position due to uncertainties in
    proper motion and acceleration over time. No uncertainty in initial position is available.

    Parameters:
    - sigma_pm Uncertainty in proper motion (mas/yr)
    - sigma_acc : Uncertainty in acceleration (mas/yr²)
    - dt : Time from reference epoch (in years)

    Returns:
    - sigma_pos : Uncertainty in predicted position at time dt (in mas)
    """
    term_mu = (dt * sigma_pm) ** 2
    term_acc = (0.5 * dt**2 * sigma_acc) ** 2
    return np.sqrt(term_mu + term_acc)

# %%
"""
Mock dataset from single epoch observations for star A
"""

# Time offset between epochs in years
dt = 10              
# Decimal-year epochs
epochs_years = np.array([2010 - dt, 2010, 2010 + dt])   
# Convert to MJD
epochs_mjd = [octo.years2mjd(float(y)) for y in epochs_years]

# Observational Data 
# Star A
ra_A = (201.6967263*u.deg).to(u.mas).value
dec_A = (-47.4795835*u.deg).to(u.mas).value
pm_ra_A = 3.563 # mas year^-1
pm_dec_A = 2.564 # mas year^-1
acc_ra_A = -0.0069 # mas year^-2
acc_dec_A = 0.0085 # mas year^-2

# Omega Centauri Center 
# We find the center to be at (α,δ) = (13:26:47.24, −47:28:46.45).
# from https://iopscience.iop.org/article/10.1088/0004-637X/710/2/1032
# reference 6 in Haberle et al. (2024; Nature, Vol. 631) 
# We assume the IMBH is located at the cluster center
ra_cm_deg = 201.696834*u.deg
dec_cm_deg = -47.479569*u.deg
# Omega Centauri centre in mas
ra_cm_mas  = ra_cm_deg.to(u.mas).value
dec_cm_mas = dec_cm_deg.to(u.mas).value

# Uncertainties 
sigma_pm_ra_A = 0.038 # mas year^-1
sigma_pm_dec_A = 0.055 # mas year^-1
sigma_acc_ra_A = 0.0083 # mas year^-2
sigma_acc_dec_A = 0.0098 # mas year^-2


# Mock future and past observations
future_ra_A  = fake_pos(ra_A,  pm_ra_A,  acc_ra_A,  dt)
future_dec_A = fake_pos(dec_A, pm_dec_A, acc_dec_A, dt)
past_ra_A    = fake_pos(ra_A,  pm_ra_A,  acc_ra_A, -dt)
past_dec_A   = fake_pos(dec_A, pm_dec_A, acc_dec_A, -dt)

future_ra_A_err  = propagate_error(sigma_pm_ra_A,  sigma_acc_ra_A,  dt)
future_dec_A_err = propagate_error(sigma_pm_dec_A, sigma_acc_dec_A, dt)
past_ra_A_err    = propagate_error(sigma_pm_ra_A,  sigma_acc_ra_A, -dt)
past_dec_A_err   = propagate_error(sigma_pm_dec_A, sigma_acc_dec_A, -dt)

# Arrays of absolute positions 
ra_vals_A  = np.array([past_ra_A,  ra_A,  future_ra_A])   # mas
dec_vals_A = np.array([past_dec_A, dec_A, future_dec_A])  # mas

# Convert to positions relative to the assumed center of mass
ra_rel_A  = ra_vals_A  - ra_cm_mas      # delta RA = companion − host  [mas]
dec_rel_A = dec_vals_A - dec_cm_mas     # delta Dec = companion − host [mas]

# Uncertainty is required for Octofitter for all positions (small uncertainty instead of zero)
ra_errs_A = [past_ra_A_err, 1e-6, future_ra_A_err]
dec_errs_A = [past_dec_A_err, 1e-6, future_dec_A_err]

# %%
print()
print("Mock future RA of star A:", (future_ra_A*u.mas).to(u.deg), "±",(future_ra_A_err*u.mas).to(u.deg))
print("Mock future DEC of star A:", (future_dec_A*u.mas).to(u.deg), "±",(future_dec_A_err*u.mas).to(u.deg))
print()
print("Mock past RA of star A:", (past_ra_A*u.mas).to(u.deg), "±",(past_ra_A_err*u.mas).to(u.deg))
print("Mock past DEC of star A:", (past_dec_A*u.mas).to(u.deg), "±",(past_dec_A_err*u.mas).to(u.deg))
print()
# Out:
# Mock future RA of star A: 201.69673610138886 deg ± 1.5630400301343755e-07 deg
# Mock future DEC of star A: -47.47957625972222 deg ± 2.0461496511892108e-07 deg
#
# Mock past RA of star A: 201.6967163069444 deg ± 1.5630400301343755e-07 deg
# Mock past DEC of star A: -47.47959050416666 deg ± 2.0461496511892108e-07 deg

# %%
"""
Mock dataset from single epoch observations for star A
"""

# Time offset between epochs in years
dt = 10              
# Decimal-year epochs
epochs_years = np.array([2010 - dt, 2010, 2010 + dt])   
# Convert to MJD
epochs_mjd = [octo.years2mjd(float(y)) for y in epochs_years]

# Observational Data 
# Star A
ra_A = (201.6967263*u.deg).to(u.mas).value
dec_A = (-47.4795835*u.deg).to(u.mas).value
pm_ra_A = 3.563 # mas year^-1
pm_dec_A = 2.564 # mas year^-1
acc_ra_A = -0.0069 # mas year^-2
acc_dec_A = 0.0085 # mas year^-2
# Omega Centauri Center 
# We find the center to be at (α,δ) = (13:26:47.24, −47:28:46.45).
# from https://iopscience.iop.org/article/10.1088/0004-637X/710/2/1032
# reference 6 in Haberle et al. (2024; Nature, Vol. 631) 
# We assume the IMBH is located at the cluster center
ra_cm_deg = 201.696834*u.deg
dec_cm_deg = -47.479569*u.deg
# Omega Centauri centre in mas
ra_cm_mas  = ra_cm_deg.to(u.mas).value
dec_cm_mas = dec_cm_deg.to(u.mas).value

# Uncertainties 
sigma_pm_ra_A = 0.038 # mas year^-1
sigma_pm_dec_A = 0.055 # mas year^-1
sigma_acc_ra_A = 0.0083 # mas year^-2
sigma_acc_dec_A = 0.0098 # mas year^-2


# Mock future and past observations
future_ra_A  = fake_pos(ra_A,  pm_ra_A,  acc_ra_A,  dt)
future_dec_A = fake_pos(dec_A, pm_dec_A, acc_dec_A, dt)
past_ra_A    = fake_pos(ra_A,  pm_ra_A,  acc_ra_A, -dt)
past_dec_A   = fake_pos(dec_A, pm_dec_A, acc_dec_A, -dt)

future_ra_A_err  = propagate_error(sigma_pm_ra_A,  sigma_acc_ra_A,  dt)
future_dec_A_err = propagate_error(sigma_pm_dec_A, sigma_acc_dec_A, dt)
past_ra_A_err    = propagate_error(sigma_pm_ra_A,  sigma_acc_ra_A, -dt)
past_dec_A_err   = propagate_error(sigma_pm_dec_A, sigma_acc_dec_A, -dt)

# Arrays of absolute positions 
ra_vals_A  = np.array([past_ra_A,  ra_A,  future_ra_A])   # mas
dec_vals_A = np.array([past_dec_A, dec_A, future_dec_A])  # mas

# Convert to positions relative to the assumed center of mass
ra_rel_A  = ra_vals_A  - ra_cm_mas      # delta RA = companion − host  [mas]
dec_rel_A = dec_vals_A - dec_cm_mas     # delta Dec = companion − host [mas]

# Uncertainty is required for Octofitter for all positions (small uncertainty instead of zero)
ra_errs_A = [past_ra_A_err, 1e-6, future_ra_A_err]
dec_errs_A = [past_dec_A_err, 1e-6, future_dec_A_err]

# %%
epochs_mjd
# Out:
# [51544.0, 55197.0, 58849.0]

# %%
"""
Orbital Calculations and Plots with Octofitter
"""
# We start by defining a likelihood object for the relative astrometry of the star.
astrom_like = octo.PlanetRelAstromLikelihood(
    # MJD
    epoch = epochs_mjd,      # Observation MJDs
    # delta RA, milliarcseconds (East is positive)
    ra = ra_rel_A.tolist(),      # Relative RA (mas)
    # delta DEC, milliarcseconds (North is positive)
    dec = dec_rel_A.tolist(),         # Relative Dec (mas)
    # Uncertainty on RA, milliarcseconds
    σ_ra = ra_errs_A,        # RA uncertainties (mas)
    # Uncertainty on DEC, milliarcseconds
	σ_dec = dec_errs_A,      # Dec uncertainties (mas)
    # Corelation between RA and DEC uncertainties
	cor= [0.0] * 3                    # No RA/Dec correlation
)

# We now define the orbiting star component of our model. 
# We specify a name, an orbital basis, our priors, and list any likelihood objects.
# Note! Change the reference epoch provided to θ_at_epoch_to_tperi from 50000 to one where your astrometry is defined
star_A = octo.Planet(
    name="A",
    basis="Visual{KepOrbit}",
    priors=
    """            
        a ~ LogUniform(0.1, 500)
        e ~ Uniform(0.0, 0.99)
        i ~ Sine()
        ω ~ UniformCircular()
        Ω ~ UniformCircular()
        θ ~ UniformCircular()
        tp = θ_at_epoch_to_tperi(system,A,55197.0) # use MJD epoch of your data here!!
    """,
    likelihoods=[astrom_like]
)


# Now we define our system, containing our star. 
# We provide it with a name (used to specify the output file names and plot legends), 
# our priors, a list of likelihood objects for the system as a whole (e.g., proper motion anomaly, radial velocity), 
# and a list of companion models.
# The name of your system determines the output file names
sys = octo.System(
    name="Omega_Cen_A",
    priors = 
    """
        M ~ truncated(Normal(1.2, 0.1), lower=0)
        plx ~ truncated(Normal(50.0, 0.02), lower=0)
    """,
    likelihoods=[],
    companions=[star_A]
)

# We then compile our model. 
# There are a few options for this function (for example, you can select the autodiff backend), but the defaults are reasonable.
model = octo.LogDensityModel(sys)

# We now fit the model. By default, this uses a Hamiltonian Monte Carlo sampler with 1000 steps of adaptation (discarded) and 1000 iterations. 
# You can pass eg, adaptation=5000, iterations=25000, if you would like more points for your plots.
# Long runtimes indiciate an error in your model
# The orbit fitting should take <30 s for this example. 
# If you find it takes much longer on your code, double check the model and priors. Is the epoch you specified for tperi the same as your data?
# Numerical errors indicate a problem with sampling 
# If you see a report that numerical errors were encountered during sampling, the results may not be statistically valid. 
# You could re-try sampling, or investigate your model for errors.
chain = octo.octofit(model)
print(chain)

# If you wish to save this summary table to a text file, you can convert it to a string like so:
summary_str = repr(chain)

# Use the octoplot function to generate plots. 
# You can use keyword arguments (see documentation) to control which output panels appear. 
# By default, they will be chosen automatically based on the kinds of data likelihoods you supply to the model.
# The output is automatically saved to a PNG file in your current folder, with a name based on the name of the System you created. 
# You can also customize this using the fname argument (see docs for more details). 
# You can change the image format (eg to PDF) by changing the file name extension.
octo.octoplot(model,chain)
# Out:
# [ Info: Determining initial positions and metric using pathfinder
# ┌ Warning: Falling back to sampling from the prior and keeping the 1000 samples with highest posterior density.
# └ @ Octofitter C:\Users\macke\.julia\packages\Octofitter\3mclS\src\initialization.jl:304
# ┌ Info: Found a sample of initial positions
# └   initial_logpost_range = (-6.413384669861055e16, -3755.7586692743657)
# [ Info: Sampling, beginning with adaptation phase...
# Sampling   0%|█                              |  ETA: 0:03:51
#                                     iterations: 2
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.5
#                                        n_steps: 1
#                                      is_accept: true
#                                acceptance_rate: 0.0
#                                    log_density: -3.2272755669394506e14
#                             hamiltonian_energy: 3.227275566939547e14
#                       hamiltonian_energy_error: 0.0
#                   max_hamiltonian_energy_error: 3.988230721401831e23
#                                     tree_depth: 0
#                                numerical_error: true
#                                      step_size: 2.1436080479289282e-8
#                                  nom_step_size: 2.1436080479289282e-8
#                                       is_adapt: true
#                                 mass_matrix: DenseEuclideanMetric(diag=[0.007151816200947224, 1.68 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  50%|████████████████               |  ETA: 0:00:40
#                                     iterations: 1002
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.8797080027937071
#                                    log_density: -1.500592907519623e6
#                             hamiltonian_energy: 1.5006459835764423e6
#                       hamiltonian_energy_error: 0.2898796144872904
#                   max_hamiltonian_energy_error: 0.3093422809615731
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  50%|████████████████               |  ETA: 0:00:40
#                                     iterations: 1005
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9830772139666565
#                                    log_density: -1.5005586442404212e6
#                             hamiltonian_energy: 1.5005729483381524e6
#                       hamiltonian_energy_error: -0.039357518777251244
#                   max_hamiltonian_energy_error: -0.21739973803050816
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  50%|████████████████               |  ETA: 0:00:40
#                                     iterations: 1008
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.987462810660096
#                                    log_density: -1.500432080485537e6
#                             hamiltonian_energy: 1.5004901992751001e6
#                       hamiltonian_energy_error: -0.10039895726367831
#                   max_hamiltonian_energy_error: -0.10752020869404078
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  51%|████████████████               |  ETA: 0:00:40
#                                     iterations: 1011
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 2047
#                                      is_accept: true
#                                acceptance_rate: 0.9953482540731651
#                                    log_density: -1.5003632491767216e6
#                             hamiltonian_energy: 1.5003707751676927e6
#                       hamiltonian_energy_error: 0.004597184248268604
#                   max_hamiltonian_energy_error: -0.22689283383078873
#                                     tree_depth: 11
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  51%|████████████████               |  ETA: 0:00:40
#                                     iterations: 1015
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.959245353449748
#                                    log_density: -1.5003209833502716e6
#                             hamiltonian_energy: 1.5003248542514702e6
#                       hamiltonian_energy_error: -0.04247584450058639
#                   max_hamiltonian_energy_error: 0.1297709927894175
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  51%|████████████████               |  ETA: 0:00:40
#                                     iterations: 1018
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9999028104221478
#                                    log_density: -1.5001511966123295e6
#                             hamiltonian_energy: 1.5001681730932728e6
#                       hamiltonian_energy_error: -0.12488433043472469
#                   max_hamiltonian_energy_error: -0.2359824189916253
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  51%|████████████████               |  ETA: 0:00:40
#                                     iterations: 1021
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9917988231950791
#                                    log_density: -1.499948455504032e6
#                             hamiltonian_energy: 1.5001068421002293e6
#                       hamiltonian_energy_error: -0.12587932427413762
#                   max_hamiltonian_energy_error: -0.21786743332631886
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  51%|████████████████               |  ETA: 0:00:39
#                                     iterations: 1023
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9828708980722626
#                                    log_density: -1.4998058869856019e6
#                             hamiltonian_energy: 1.4998330815155343e6
#                       hamiltonian_energy_error: 0.028377388836815953
#                   max_hamiltonian_energy_error: 0.054030216531828046
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  51%|████████████████               |  ETA: 0:00:39
#                                     iterations: 1026
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9792286549678134
#                                    log_density: -1.4997400272318278e6
#                             hamiltonian_energy: 1.4997473992385825e6
#                       hamiltonian_energy_error: 0.04522456135600805
#                   max_hamiltonian_energy_error: 0.08605232276022434
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  51%|████████████████               |  ETA: 0:00:39
#                                     iterations: 1029
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9837437491318958
#                                    log_density: -1.4995917265335438e6
#                             hamiltonian_energy: 1.4996383423041173e6
#                       hamiltonian_energy_error: 0.013398627284914255
#                   max_hamiltonian_energy_error: 0.06222257390618324
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  52%|████████████████               |  ETA: 0:00:39
#                                     iterations: 1032
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9618039603327861
#                                    log_density: -1.4994290900709168e6
#                             hamiltonian_energy: 1.499473371830901e6
#                       hamiltonian_energy_error: -0.22980974707752466
#                   max_hamiltonian_energy_error: -0.5851580984890461
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  52%|█████████████████              |  ETA: 0:00:39
#                                     iterations: 1034
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9734073092665632
#                                    log_density: -1.4993548229174898e6
#                             hamiltonian_energy: 1.4993870949076435e6
#                       hamiltonian_energy_error: -0.049647331703454256
#                   max_hamiltonian_energy_error: 0.09377017663791776
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  52%|█████████████████              |  ETA: 0:00:39
#                                     iterations: 1037
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 2047
#                                      is_accept: true
#                                acceptance_rate: 0.9578919229900472
#                                    log_density: -1.4992352099700174e6
#                             hamiltonian_energy: 1.499265446417929e6
#                       hamiltonian_energy_error: 0.024136840598657727
#                   max_hamiltonian_energy_error: 0.11911887023597956
#                                     tree_depth: 11
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  52%|█████████████████              |  ETA: 0:00:39
#                                     iterations: 1040
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.992363382023248
#                                    log_density: -1.4990467670574766e6
#                             hamiltonian_energy: 1.4991306614837837e6
#                       hamiltonian_energy_error: -0.018233382375910878
#                   max_hamiltonian_energy_error: -0.04308481281623244
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  52%|█████████████████              |  ETA: 0:00:39
#                                     iterations: 1042
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.7797916132748954
#                                    log_density: -1.4990079012855e6
#                             hamiltonian_energy: 1.4990265088623276e6
#                       hamiltonian_energy_error: 0.1762104572262615
#                   max_hamiltonian_energy_error: 0.5670050231274217
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  52%|█████████████████              |  ETA: 0:00:39
#                                     iterations: 1044
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.8341373534444092
#                                    log_density: -1.498869028420992e6
#                             hamiltonian_energy: 1.4989247582479976e6
#                       hamiltonian_energy_error: 0.4082712789531797
#                   max_hamiltonian_energy_error: 0.427270726300776
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  52%|█████████████████              |  ETA: 0:00:39
#                                     iterations: 1047
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9535374933695195
#                                    log_density: -1.4987598373300948e6
#                             hamiltonian_energy: 1.4988433685818801e6
#                       hamiltonian_energy_error: 0.08109075017273426
#                   max_hamiltonian_energy_error: 0.15042297635227442
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  52%|█████████████████              |  ETA: 0:00:39
#                                     iterations: 1049
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9966130831072433
#                                    log_density: -1.4985987342634972e6
#                             hamiltonian_energy: 1.4987066973466156e6
#                       hamiltonian_energy_error: -0.14702824084088206
#                   max_hamiltonian_energy_error: -0.4238610044121742
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  53%|█████████████████              |  ETA: 0:00:39
#                                     iterations: 1052
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9483772236533912
#                                    log_density: -1.4984736930592633e6
#                             hamiltonian_energy: 1.49852623985774e6
#                       hamiltonian_energy_error: 0.03534425818361342
#                   max_hamiltonian_energy_error: 0.11730115814134479
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  53%|█████████████████              |  ETA: 0:00:39
#                                     iterations: 1054
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.8093682814251568
#                                    log_density: -1.4984164164860211e6
#                             hamiltonian_energy: 1.4984740734672225e6
#                       hamiltonian_energy_error: 0.024468474555760622
#                   max_hamiltonian_energy_error: 0.4696568890940398
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  53%|█████████████████              |  ETA: 0:00:39
#                                     iterations: 1056
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.8598573003622305
#                                    log_density: -1.4982451890883315e6
#                             hamiltonian_energy: 1.4983883684467175e6
#                       hamiltonian_energy_error: -0.023062294581905007
#                   max_hamiltonian_energy_error: 0.4224191040266305
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  53%|█████████████████              |  ETA: 0:00:39
#                                     iterations: 1058
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9978543952279998
#                                    log_density: -1.4981920361060994e6
#                             hamiltonian_energy: 1.4982396524967435e6
#                       hamiltonian_energy_error: -0.04495444893836975
#                   max_hamiltonian_energy_error: -0.08743505668826401
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  53%|█████████████████              |  ETA: 0:00:38
#                                     iterations: 1060
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9903821738906301
#                                    log_density: -1.497933836508544e6
#                             hamiltonian_energy: 1.498048521318262e6
#                       hamiltonian_energy_error: 0.069252046989277
#                   max_hamiltonian_energy_error: -0.3216570436488837
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  53%|█████████████████              |  ETA: 0:00:38
#                                     iterations: 1062
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.8574823518670601
#                                    log_density: -1.4978353864112857e6
#                             hamiltonian_energy: 1.4979254529449076e6
#                       hamiltonian_energy_error: 0.2581363143399358
#                   max_hamiltonian_energy_error: 0.591650095069781
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  53%|█████████████████              |  ETA: 0:00:38
#                                     iterations: 1064
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9067511888916414
#                                    log_density: -1.4975941204842902e6
#                             hamiltonian_energy: 1.4977781593592456e6
#                       hamiltonian_energy_error: -0.912641282659024
#                   max_hamiltonian_energy_error: -1.000228073215112
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  53%|█████████████████              |  ETA: 0:00:38
#                                     iterations: 1068
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9684228343213572
#                                    log_density: -1.4975047096786594e6
#                             hamiltonian_energy: 1.4975702348691323e6
#                       hamiltonian_energy_error: 0.1085592987947166
#                   max_hamiltonian_energy_error: -0.20257909805513918
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  54%|█████████████████              |  ETA: 0:00:38
#                                     iterations: 1070
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9996284117520904
#                                    log_density: -1.4973406123464901e6
#                             hamiltonian_energy: 1.4974786175716608e6
#                       hamiltonian_energy_error: -0.21901423088274896
#                   max_hamiltonian_energy_error: -0.33148140576668084
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  54%|█████████████████              |  ETA: 0:00:38
#                                     iterations: 1073
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.7412395960972402
#                                    log_density: -1.497302732230914e6
#                             hamiltonian_energy: 1.497315406240426e6
#                       hamiltonian_energy_error: -0.04208984482102096
#                   max_hamiltonian_energy_error: 0.833769281161949
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  54%|█████████████████              |  ETA: 0:00:38
#                                     iterations: 1075
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9937421803819579
#                                    log_density: -1.4972035480412599e6
#                             hamiltonian_energy: 1.4972881591627821e6
#                       hamiltonian_energy_error: -0.23258064035326242
#                   max_hamiltonian_energy_error: -0.3924838157836348
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  54%|█████████████████              |  ETA: 0:00:38
#                                     iterations: 1077
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.8894734234454764
#                                    log_density: -1.4971875041036943e6
#                             hamiltonian_energy: 1.4971913932659582e6
#                       hamiltonian_energy_error: 0.18704763893038034
#                   max_hamiltonian_energy_error: 0.34278169833123684
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  54%|█████████████████              |  ETA: 0:00:38
#                                     iterations: 1079
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.8284483163462917
#                                    log_density: -1.497043389447826e6
#                             hamiltonian_energy: 1.4971109227559227e6
#                       hamiltonian_energy_error: 0.13260817131958902
#                   max_hamiltonian_energy_error: 0.39004787523299456
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  54%|█████████████████              |  ETA: 0:00:38
#                                     iterations: 1081
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.8398223763683429
#                                    log_density: -1.4968288046413849e6
#                             hamiltonian_energy: 1.496994264807913e6
#                       hamiltonian_energy_error: 0.3713328300509602
#                   max_hamiltonian_energy_error: 0.6492630934808403
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  54%|█████████████████              |  ETA: 0:00:38
#                                     iterations: 1083
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9938883528047562
#                                    log_density: -1.4966359294775159e6
#                             hamiltonian_energy: 1.4967573268925783e6
#                       hamiltonian_energy_error: -0.38410549820400774
#                   max_hamiltonian_energy_error: -0.49885709723457694
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  54%|█████████████████              |  ETA: 0:00:38
#                                     iterations: 1086
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.7900746444856257
#                                    log_density: -1.496459762629229e6
#                             hamiltonian_energy: 1.4965820560201835e6
#                       hamiltonian_energy_error: 0.0651439530774951
#                   max_hamiltonian_energy_error: 0.5310142715461552
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  54%|█████████████████              |  ETA: 0:00:38
#                                     iterations: 1088
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.8179424899291435
#                                    log_density: -1.4963128224373185e6
#                             hamiltonian_energy: 1.4963711711394582e6
#                       hamiltonian_energy_error: 0.500143735203892
#                   max_hamiltonian_energy_error: 0.5180354681797326
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  54%|█████████████████              |  ETA: 0:00:38
#                                     iterations: 1090
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.8570346810409699
#                                    log_density: -1.4961730413720354e6
#                             hamiltonian_energy: 1.4962388899482954e6
#                       hamiltonian_energy_error: -0.37895593978464603
#                   max_hamiltonian_energy_error: 0.6452623568475246
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  55%|█████████████████              |  ETA: 0:00:38
#                                     iterations: 1092
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9948223334608958
#                                    log_density: -1.4961362192968905e6
#                             hamiltonian_energy: 1.4961469953325808e6
#                       hamiltonian_energy_error: 0.004232845501974225
#                   max_hamiltonian_energy_error: -0.08465228462591767
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  55%|█████████████████              |  ETA: 0:00:38
#                                     iterations: 1094
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9600512250998011
#                                    log_density: -1.4960573747003637e6
#                             hamiltonian_energy: 1.4961442390586843e6
#                       hamiltonian_energy_error: 0.09749745414592326
#                   max_hamiltonian_energy_error: -0.31761224707588553
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  55%|██████████████████             |  ETA: 0:00:37
#                                     iterations: 1100
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.7125214341014003
#                                    log_density: -1.4957166754217828e6
#                             hamiltonian_energy: 1.4957678610120493e6
#                       hamiltonian_energy_error: 0.052233071299269795
#                   max_hamiltonian_energy_error: 0.7279585455544293
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  55%|██████████████████             |  ETA: 0:00:37
#                                     iterations: 1103
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9932402143997799
#                                    log_density: -1.4955656959538208e6
#                             hamiltonian_energy: 1.495591158708416e6
#                       hamiltonian_energy_error: -0.03430345677770674
#                   max_hamiltonian_energy_error: -0.11928400094620883
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  55%|██████████████████             |  ETA: 0:00:37
#                                     iterations: 1106
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9694717737336234
#                                    log_density: -1.4953255692278945e6
#                             hamiltonian_energy: 1.4953715402857633e6
#                       hamiltonian_energy_error: 0.01659270445816219
#                   max_hamiltonian_energy_error: 0.06444239639677107
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  55%|██████████████████             |  ETA: 0:00:37
#                                     iterations: 1109
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9852528351585393
#                                    log_density: -1.4952480698182103e6
#                             hamiltonian_energy: 1.4952628423537666e6
#                       hamiltonian_energy_error: -0.057076431112363935
#                   max_hamiltonian_energy_error: -0.6799805550836027
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  56%|██████████████████             |  ETA: 0:00:37
#                                     iterations: 1112
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.06
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9999116207538501
#                                    log_density: -1.4950705147394422e6
#                             hamiltonian_energy: 1.4952069387592801e6
#                       hamiltonian_energy_error: 0.001966151176020503
#                   max_hamiltonian_energy_error: -0.18486378295347095
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
# ...
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.03
#                                        n_steps: 2047
#                                      is_accept: true
#                                acceptance_rate: 0.8294514581806062
#                                    log_density: -1.4529721563011792e6
#                             hamiltonian_energy: 1.4529854940845487e6
#                       hamiltonian_energy_error: -0.0925224726088345
#                   max_hamiltonian_energy_error: 0.4963384778238833
#                                     tree_depth: 11
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  99%|███████████████████████████████|  ETA: 0:00:01
#                                     iterations: 1972
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.03
#                                        n_steps: 2047
#                                      is_accept: true
#                                acceptance_rate: 0.9364100119118399
#                                    log_density: -1.452844536071305e6
#                             hamiltonian_energy: 1.4528533241325694e6
#                       hamiltonian_energy_error: 0.18796477653086185
#                   max_hamiltonian_energy_error: 0.24541629548184574
#                                     tree_depth: 11
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  99%|███████████████████████████████|  ETA: 0:00:01
#                                     iterations: 1975
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.03
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.8216955873882203
#                                    log_density: -1.4527546754105755e6
#                             hamiltonian_energy: 1.4527962113975661e6
#                       hamiltonian_energy_error: 0.08557827142067254
#                   max_hamiltonian_energy_error: 0.6333804638125002
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  99%|███████████████████████████████|  ETA: 0:00:01
#                                     iterations: 1977
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.03
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9208111368919509
#                                    log_density: -1.4526692882900261e6
#                             hamiltonian_energy: 1.452706104169319e6
#                       hamiltonian_energy_error: 0.06329430732876062
#                   max_hamiltonian_energy_error: 0.17012291634455323
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  99%|███████████████████████████████|  ETA: 0:00:01
#                                     iterations: 1979
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.03
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9815944961047244
#                                    log_density: -1.452627988607677e6
#                             hamiltonian_energy: 1.4526328590104477e6
#                       hamiltonian_energy_error: -0.021555989980697632
#                   max_hamiltonian_energy_error: -0.06953870062716305
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  99%|███████████████████████████████|  ETA: 0:00:01
#                                     iterations: 1981
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.03
#                                        n_steps: 2047
#                                      is_accept: true
#                                acceptance_rate: 0.8907048588156633
#                                    log_density: -1.4525842519562403e6
#                             hamiltonian_energy: 1.452598596034948e6
#                       hamiltonian_energy_error: -0.06591178220696747
#                   max_hamiltonian_energy_error: 0.3536077430471778
#                                     tree_depth: 11
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  99%|███████████████████████████████|  ETA: 0:00:01
#                                     iterations: 1984
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.03
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9491859935510651
#                                    log_density: -1.4523689350776973e6
#                             hamiltonian_energy: 1.4524131865484943e6
#                       hamiltonian_energy_error: 0.0038988986052572727
#                   max_hamiltonian_energy_error: 0.20125998626463115
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  99%|███████████████████████████████|  ETA: 0:00:01
#                                     iterations: 1987
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.03
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.93493292570498
#                                    log_density: -1.4521592490910597e6
#                             hamiltonian_energy: 1.452264942265935e6
#                       hamiltonian_energy_error: -0.049394327914342284
#                   max_hamiltonian_energy_error: 0.17820407333783805
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  99%|███████████████████████████████|  ETA: 0:00:01
#                                     iterations: 1989
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.03
#                                        n_steps: 2047
#                                      is_accept: true
#                                acceptance_rate: 0.9266232099853801
#                                    log_density: -1.4521132397676697e6
#                             hamiltonian_energy: 1.4521334139821755e6
#                       hamiltonian_energy_error: 0.07583061489276588
#                   max_hamiltonian_energy_error: 0.17011965601705015
#                                     tree_depth: 11
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  99%|███████████████████████████████|  ETA: 0:00:00
#                                     iterations: 1991
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.03
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9945600480101922
#                                    log_density: -1.4519624211087504e6
#                             hamiltonian_energy: 1.4520890242757369e6
#                       hamiltonian_energy_error: -0.04886118764989078
#                   max_hamiltonian_energy_error: -0.11728551331907511
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  99%|███████████████████████████████|  ETA: 0:00:00
#                                     iterations: 1993
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.03
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9561441369655598
#                                    log_density: -1.4518157412916187e6
#                             hamiltonian_energy: 1.451929326301499e6
#                       hamiltonian_energy_error: -0.07083801622502506
#                   max_hamiltonian_energy_error: 0.19862028257921338
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  99%|███████████████████████████████|  ETA: 0:00:00
#                                     iterations: 1997
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.03
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.8573152611567398
#                                    log_density: -1.4515751298321155e6
#                             hamiltonian_energy: 1.4517381347243772e6
#                       hamiltonian_energy_error: 0.162632389459759
#                   max_hamiltonian_energy_error: 0.40389195224270225
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling  99%|███████████████████████████████|  ETA: 0:00:00
#                                     iterations: 1999
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.03
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9671171819448525
#                                    log_density: -1.4514027415110986e6
#                             hamiltonian_energy: 1.4515138825109403e6
#                       hamiltonian_energy_error: 0.014164425199851394
#                   max_hamiltonian_energy_error: 0.09432800184004009
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                 mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Sampling 100%|███████████████████████████████| Time: 0:01:47
#                                     iterations: 2000
#                    ratio_divergent_transitions: 0.0
#    ratio_divergent_transitions_during_adaption: 0.03
#                                        n_steps: 4095
#                                      is_accept: true
#                                acceptance_rate: 0.9097174968126439
#                                    log_density: -1.451358808338202e6
#                             hamiltonian_energy: 1.451408541688047e6
#                       hamiltonian_energy_error: -0.01797490892931819
#                   max_hamiltonian_energy_error: 0.23890091478824615
#                                     tree_depth: 12
#                                numerical_error: false
#                                      step_size: 5.433347676902571e-7
#                                  nom_step_size: 5.433347676902571e-7
#                                       is_adapt: false
#                                    mass_matrix: DenseEuclideanMetric(diag=[1.1508155227878822e-5, 1.3 ...])
# [ Info: Sampling compete. Building chains.
# ┌ Warning: Maximum tree depth hit in more than 10% of iterations (reduced efficiency)
# │   max_tree_depth_frac = 0.799
# └ @ Octofitter C:\Users\macke\.julia\packages\Octofitter\3mclS\src\sampling.jl:780
# ┌ Info: You can control the panels included by `octoplot` by passing keyword arguments. Currently selected:
# │   show_astrom = true
# │   show_physical_orbit = false
# │   show_astrom_time = true
# │   show_hgca = false
# │   show_mass = false
# │   show_rv = false
# │   show_relative_rv = false
# └   show_hipparcos = false
# Sampling report for chain:
# mean_accept                 = 0.9308746893938569
# ratio_divergent_transitions = 0.0
# mean_tree_depth             = 11.793
# max_tree_depth_frac         = 0.799
# total_steps                 = 7377464
# μs/step                     = 14.6
# MCMC chain (1000×28×1 Array{Float64, 3})
# [ Info: pass true or false for each of these arguments to suppress this message.

# %%
"""
Saving your chain:
Variables can be retrieved from the chains using the following syntax:
    sma_planet_b = chain["b_a",:,:] 
The first index is the name of the variable in the model (as a string or symbol).
Planet-specific parameters are prefixed with the planet's name and an underscore (e.g., 'A_a' for semi-major axis of planet A).
"""

# --- Extract and print best-fit orbital parameters for planet A (16th, 50th, 84th percentiles) ---

# Semi-major axis in astronomical units
print("Semi-major axis [AU]:", np.percentile(chain["A_a"], [16, 50, 84]))

# Eccentricity (unitless, range: 0–1)
print("Eccentricity:", np.percentile(chain["A_e"], [16, 50, 84]))

# Orbital inclination in degrees (0° = face-on, 90° = edge-on)
print("Inclination [deg]:", np.percentile(chain["A_i"], [16, 50, 84]))

# Argument of periastron (angle from ascending node to periastron, in degrees)
print("Argument of periastron [deg]:", np.percentile(chain["A_ω"], [16, 50, 84]))

# Longitude of the ascending node (angle of orbit's orientation in space)
print("Longitude of ascending node [deg]:", np.percentile(chain["A_Ω"], [16, 50, 84]))

# Time of periastron passage in Modified Julian Date (MJD)
print("Time of periastron passage [MJD]:", np.percentile(chain["A_tp"], [16, 50, 84]))

# Convert MJD to calendar years (ISO format) using Octofitter's Julian date conversion
tp_mjds = np.percentile(chain["A_tp"], [16, 50, 84])
tp_years_octo = [octo.mjd2date(float(mjd)) for mjd in tp_mjds]
print("Time of periastron passage [years]:", tp_years_octo)

# Total system mass (usually primary + companion) in solar masses
print("Total Mass [Solar Masses]:", np.percentile(chain["M"], [16, 50, 84]))
# Out:
# Semi-major axis [AU]: [10.51029714 10.56064343 10.61866124]
# Eccentricity: [0.02734883 0.02735839 0.02736589]
# Inclination [deg]: [2.34645682 2.34691656 2.34730104]
# Argument of periastron [deg]: [-1.02026237 -1.02024606 -1.02022847]
# Longitude of ascending node [deg]: [-2.63624548 -2.63614744 -2.63600837]
# Time of periastron passage [MJD]: [43727.55137876 43842.03325912 43940.91156006]
# Time of periastron passage [years]: [datetime.datetime(1978, 8, 7, 13, 13, 59), datetime.datetime(1978, 11, 30, 0, 47, 54), datetime.datetime(1979, 3, 8, 21, 52, 39)]
# Total Mass [Solar Masses]: [1.18855325 1.19298135 1.19685669]

# %%
# Orbit Plot
A_plot = octo.octoplot(model,chain, show_physical_orbit = True)
A_plot

# %%
# Corner Plot
A_corner_plot = octo.octocorner(model,chain,small=True) 
A_corner_plot

# %%
"""
Observed 2D Velocities and Accelerations 
----------------------------------------
Observational data for 7 high-velocity stars in Omega Centauri
Calculations of plane-of-sky accelerations and propagation of uncertainties
"""

# ========================================================
# 1. Input: Measured Proper Motion Velocities (v2D)
# ========================================================

# 2D velocities in the plane of the sky [km/s]
# Sources A–G
v2D = np.array([113.0, 66.6, 94.9, 77.9, 69.6, 67.4, 66.2]) * u.km / u.s

# Corresponding 1σ uncertainties [km/s]
v2D_err = np.array([1.1, 4.1, 1.7, 2.0, 0.8, 0.4, 1.9]) * u.km / u.s

# ========================================================
# 2. Input: Angular Accelerations from Astrometry (RA/Dec)
# ========================================================

# Accelerations in Right Ascension [mas/yr²]
a_ra = np.array([-0.0069, 0.0702, 0.0028, 0.0357, 0.0072, 0.0052, -0.0197]) * u.mas / u.yr**2
a_ra_err = np.array([0.0083, 0.0239, 0.0333, 0.0177, 0.0042, 0.0038, 0.0267]) * u.mas / u.yr**2

# Accelerations in Declination [mas/yr²]
a_dec = np.array([0.0085, 0.0228, -0.0060, -0.0194, -0.0009, -0.0015, 0.0173]) * u.mas / u.yr**2
a_dec_err = np.array([0.0098, 0.0157, 0.0123, 0.0162, 0.0075, 0.0038, 0.0170]) * u.mas / u.yr**2

# ========================================================
# 3. Total Angular Acceleration and Uncertainty (Plane-of-Sky)
# ========================================================

# Total angular acceleration [mas/yr²]
a_total_masyr2 = np.sqrt(a_ra**2 + a_dec**2)

# Propagate uncertainty using partial derivatives
a_total_masyr2_err = np.sqrt(
    (a_ra * a_ra_err / a_total_masyr2)**2 +
    (a_dec * a_dec_err / a_total_masyr2)**2
)

# ========================================================
# 4. Conversion to Physical Acceleration [km/s²]
# ========================================================

# Convert angular acceleration to physical acceleration using cluster distance
a_total = utils.masyr2_to_kms2(a_masyr2=a_total_masyr2, distance_km=utils.distance_km)
a_total_err = utils.masyr2_to_kms2(a_masyr2=a_total_masyr2_err, distance_km=utils.distance_km)

# ========================================================
# 5. Create Summary Data Table
# ========================================================

# Build astropy table of all values
star_data = Table({
    "v2D": v2D,
    "v2D_err": v2D_err,
    "a_ra": a_ra,
    "a_ra_err": a_ra_err,
    "a_dec": a_dec,
    "a_dec_err": a_dec_err,
    "a_total": a_total,
    "a_total_err": a_total_err,
})

# Final table 
star_data
